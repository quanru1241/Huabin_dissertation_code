# %%
import pandas as pd
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from pycaret.regression import *
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from scipy.stats import pearsonr


# --------------------- 1. Load & Merge Data ---------------------
met_ds = xr.open_dataset("US-UMB_2000-2014_FLUXNET2015_Met.nc")
flux_ds = xr.open_dataset("US-UMB_2000-2014_FLUXNET2015_Flux.nc")
met_df = met_ds.to_dataframe().reset_index()
flux_df = flux_ds.to_dataframe().reset_index()
df = pd.merge_asof(met_df.sort_values('time'), flux_df.sort_values('time'), on='time')

features_raw = ['SWdown', 'LWdown', 'Tair', 'Qair', 'RH', 'Psurf', 'Wind',
                'CO2air', 'VPD', 'LAI', 'Ustar']
target_vars = ['GPP', 'NEE']
df = df[['time'] + features_raw + target_vars].dropna()

# 派生特征
df['SW_LAI'] = df['SWdown'] * df['LAI']
df['RH_Tair'] = df['RH'] * df['Tair']
df['SWdown_lag1'] = df['SWdown'].shift(1)
df['Tair_lag1'] = df['Tair'].shift(1)
df = df.dropna()

df = df.set_index('time').sort_index()
features = features_raw + ['SW_LAI', 'RH_Tair', 'SWdown_lag1', 'Tair_lag1']

# --------------------- 2. Split Train/Test ---------------------
split_idx = int(len(df) * 0.7)
train_df = df.iloc[:split_idx]
test_df = df.iloc[split_idx:]

# --------------------- 3. AutoML 函数 ---------------------
def run_pycaret_automl(target_var):
    print(f"\n===================== [AutoML - {target_var}] =====================")

    data = pd.concat([train_df[features], train_df[target_var]], axis=1)
    data.reset_index(drop=True, inplace=True)

    # ✅ setup 兼容 PyCaret 3.x 的参数设置
    exp = setup(
        data=data,
        target=target_var,
        session_id=42,
        train_size=0.999,
        fold_strategy='timeseries',
        fold=3,
        fold_shuffle=False,
        data_split_shuffle=False,
        preprocess=True,
        numeric_features=features,
        remove_multicollinearity=True,
        multicollinearity_threshold=0.95
    )

    # 自动模型比较
    best = compare_models(sort='R2')
    
    # 预测 + 指标评估
    test_data = test_df[features].copy().reset_index(drop=True)
    test_target = test_df[target_var].copy().reset_index(drop=True)
    pred = predict_model(best, data=test_data)

    y_pred = pred['prediction_label'].values
    y_true = test_target.values

    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    rho, _ = pearsonr(y_true, y_pred)

    print(f"Best Model: {best}")
    print(f"R² (Coefficient of Determination):   {r2:.4f}")
    print(f"RMSE (Root Mean Squared Error):      {rmse:.4f}")
    print(f"MAE (Mean Absolute Error):           {mae:.4f}")
    print(f"ρ (Pearson Correlation Coefficient): {rho:.4f}")

    # 可视化：预测 vs 实测
    plt.figure(figsize=(12, 4))
    plt.plot(test_df.index, y_true, label="Observed", alpha=0.7)
    plt.plot(test_df.index, y_pred, label="Predicted", alpha=0.7)
    plt.title(f"{target_var} Prediction (AutoML - {best})")
    plt.legend()
    plt.tight_layout()
    plt.show()

# --------------------- 4. Run ---------------------
run_pycaret_automl('GPP')
run_pycaret_automl('NEE')
# Out:
# ===================== [AutoML - GPP] =====================
# <style type="text/css">
# #T_f82ee_row8_col1, #T_f82ee_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f82ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f82ee_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f82ee_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f82ee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f82ee_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f82ee_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f82ee_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f82ee_row1_col1" class="data row1 col1" >GPP</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f82ee_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f82ee_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f82ee_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f82ee_row3_col1" class="data row3 col1" >(92046, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f82ee_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f82ee_row4_col1" class="data row4 col1" >(92046, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f82ee_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f82ee_row5_col1" class="data row5 col1" >(91953, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f82ee_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f82ee_row6_col1" class="data row6 col1" >(93, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f82ee_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f82ee_row7_col1" class="data row7 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f82ee_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_f82ee_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f82ee_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_f82ee_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f82ee_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_f82ee_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f82ee_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_f82ee_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f82ee_row12_col0" class="data row12 col0" >Remove multicollinearity</td>
#       <td id="T_f82ee_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f82ee_row13_col0" class="data row13 col0" >Multicollinearity threshold</td>
#       <td id="T_f82ee_row13_col1" class="data row13 col1" >0.950000</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f82ee_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_f82ee_row14_col1" class="data row14 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f82ee_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_f82ee_row15_col1" class="data row15 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f82ee_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_f82ee_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f82ee_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_f82ee_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f82ee_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_f82ee_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f82ee_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_f82ee_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f82ee_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f82ee_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_f82ee_row20_col1" class="data row20 col1" >f9d1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a1224 th {
#   text-align: left;
# }
# #T_a1224_row0_col0, #T_a1224_row0_col5, #T_a1224_row0_col6, #T_a1224_row1_col0, #T_a1224_row1_col1, #T_a1224_row1_col2, #T_a1224_row1_col3, #T_a1224_row1_col4, #T_a1224_row1_col6, #T_a1224_row2_col0, #T_a1224_row2_col1, #T_a1224_row2_col2, #T_a1224_row2_col3, #T_a1224_row2_col4, #T_a1224_row2_col5, #T_a1224_row3_col0, #T_a1224_row3_col1, #T_a1224_row3_col2, #T_a1224_row3_col3, #T_a1224_row3_col4, #T_a1224_row3_col5, #T_a1224_row3_col6, #T_a1224_row4_col0, #T_a1224_row4_col1, #T_a1224_row4_col2, #T_a1224_row4_col3, #T_a1224_row4_col4, #T_a1224_row4_col5, #T_a1224_row4_col6, #T_a1224_row5_col0, #T_a1224_row5_col1, #T_a1224_row5_col2, #T_a1224_row5_col3, #T_a1224_row5_col4, #T_a1224_row5_col5, #T_a1224_row5_col6, #T_a1224_row6_col0, #T_a1224_row6_col1, #T_a1224_row6_col2, #T_a1224_row6_col3, #T_a1224_row6_col4, #T_a1224_row6_col5, #T_a1224_row6_col6, #T_a1224_row7_col0, #T_a1224_row7_col1, #T_a1224_row7_col2, #T_a1224_row7_col3, #T_a1224_row7_col4, #T_a1224_row7_col5, #T_a1224_row7_col6, #T_a1224_row8_col0, #T_a1224_row8_col1, #T_a1224_row8_col2, #T_a1224_row8_col3, #T_a1224_row8_col4, #T_a1224_row8_col5, #T_a1224_row8_col6, #T_a1224_row9_col0, #T_a1224_row9_col1, #T_a1224_row9_col2, #T_a1224_row9_col3, #T_a1224_row9_col4, #T_a1224_row9_col5, #T_a1224_row9_col6, #T_a1224_row10_col0, #T_a1224_row10_col1, #T_a1224_row10_col2, #T_a1224_row10_col3, #T_a1224_row10_col4, #T_a1224_row10_col5, #T_a1224_row10_col6, #T_a1224_row11_col0, #T_a1224_row11_col1, #T_a1224_row11_col2, #T_a1224_row11_col3, #T_a1224_row11_col4, #T_a1224_row11_col5, #T_a1224_row11_col6, #T_a1224_row12_col0, #T_a1224_row12_col1, #T_a1224_row12_col2, #T_a1224_row12_col3, #T_a1224_row12_col4, #T_a1224_row12_col5, #T_a1224_row12_col6, #T_a1224_row13_col0, #T_a1224_row13_col1, #T_a1224_row13_col2, #T_a1224_row13_col3, #T_a1224_row13_col4, #T_a1224_row13_col5, #T_a1224_row13_col6, #T_a1224_row14_col0, #T_a1224_row14_col1, #T_a1224_row14_col2, #T_a1224_row14_col3, #T_a1224_row14_col4, #T_a1224_row14_col5, #T_a1224_row14_col6, #T_a1224_row15_col0, #T_a1224_row15_col1, #T_a1224_row15_col2, #T_a1224_row15_col3, #T_a1224_row15_col4, #T_a1224_row15_col5, #T_a1224_row15_col6, #T_a1224_row16_col0, #T_a1224_row16_col1, #T_a1224_row16_col2, #T_a1224_row16_col3, #T_a1224_row16_col4, #T_a1224_row16_col5, #T_a1224_row16_col6, #T_a1224_row17_col0, #T_a1224_row17_col1, #T_a1224_row17_col2, #T_a1224_row17_col3, #T_a1224_row17_col4, #T_a1224_row17_col5, #T_a1224_row17_col6, #T_a1224_row18_col0, #T_a1224_row18_col1, #T_a1224_row18_col2, #T_a1224_row18_col3, #T_a1224_row18_col4, #T_a1224_row18_col5, #T_a1224_row18_col6, #T_a1224_row19_col0, #T_a1224_row19_col1, #T_a1224_row19_col2, #T_a1224_row19_col3, #T_a1224_row19_col4, #T_a1224_row19_col5, #T_a1224_row19_col6 {
#   text-align: left;
# }
# #T_a1224_row0_col1, #T_a1224_row0_col2, #T_a1224_row0_col3, #T_a1224_row0_col4, #T_a1224_row1_col5, #T_a1224_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a1224_row0_col7, #T_a1224_row1_col7, #T_a1224_row2_col7, #T_a1224_row3_col7, #T_a1224_row4_col7, #T_a1224_row5_col7, #T_a1224_row6_col7, #T_a1224_row7_col7, #T_a1224_row8_col7, #T_a1224_row9_col7, #T_a1224_row10_col7, #T_a1224_row11_col7, #T_a1224_row13_col7, #T_a1224_row14_col7, #T_a1224_row15_col7, #T_a1224_row16_col7, #T_a1224_row17_col7, #T_a1224_row18_col7, #T_a1224_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a1224_row12_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a1224">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1224_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a1224_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a1224_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a1224_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a1224_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a1224_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a1224_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a1224_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1224_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_a1224_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_a1224_row0_col1" class="data row0 col1" >1.2019</td>
#       <td id="T_a1224_row0_col2" class="data row0 col2" >5.1101</td>
#       <td id="T_a1224_row0_col3" class="data row0 col3" >2.2285</td>
#       <td id="T_a1224_row0_col4" class="data row0 col4" >0.9074</td>
#       <td id="T_a1224_row0_col5" class="data row0 col5" >0.3796</td>
#       <td id="T_a1224_row0_col6" class="data row0 col6" >5.1266</td>
#       <td id="T_a1224_row0_col7" class="data row0 col7" >3.5433</td>
#     </tr>
#     <tr>
#       <th id="T_a1224_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_a1224_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_a1224_row1_col1" class="data row1 col1" >1.2258</td>
#       <td id="T_a1224_row1_col2" class="data row1 col2" >5.2689</td>
#       <td id="T_a1224_row1_col3" class="data row1 col3" >2.2659</td>
#       <td id="T_a1224_row1_col4" class="data row1 col4" >0.9041</td>
#       <td id="T_a1224_row1_col5" class="data row1 col5" >0.3794</td>
#       <td id="T_a1224_row1_col6" class="data row1 col6" >5.7155</td>
#       <td id="T_a1224_row1_col7" class="data row1 col7" >17.4333</td>
#     </tr>
#     <tr>
#       <th id="T_a1224_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_a1224_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a1224_row2_col1" class="data row2 col1" >1.2067</td>
#       <td id="T_a1224_row2_col2" class="data row2 col2" >5.3230</td>
#       <td id="T_a1224_row2_col3" class="data row2 col3" >2.2739</td>
#       <td id="T_a1224_row2_col4" class="data row2 col4" >0.9034</td>
#       <td id="T_a1224_row2_col5" class="data row2 col5" >0.4066</td>
#       <td id="T_a1224_row2_col6" class="data row2 col6" >2.6668</td>
#       <td id="T_a1224_row2_col7" class="data row2 col7" >10.9367</td>
#     </tr>
#     <tr>
#       <th id="T_a1224_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_a1224_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_a1224_row3_col1" class="data row3 col1" >1.2160</td>
#       <td id="T_a1224_row3_col2" class="data row3 col2" >5.3845</td>
#       <td id="T_a1224_row3_col3" class="data row3 col3" >2.2900</td>
#       <td id="T_a1224_row3_col4" class="data row3 col4" >0.9022</td>
#       <td id="T_a1224_row3_col5" class="data row3 col5" >0.4076</td>
#       <td id="T_a1224_row3_col6" class="data row3 col6" >2.7737</td>
#       <td id="T_a1224_row3_col7" class="data row3 col7" >12.5400</td>
#     </tr>
#     <tr>
#       <th id="T_a1224_level0_row4" class="row_heading level0 row4" >catboost</th>
#       <td id="T_a1224_row4_col0" class="data row4 col0" >CatBoost Regressor</td>
#       <td id="T_a1224_row4_col1" class="data row4 col1" >1.2277</td>
#       <td id="T_a1224_row4_col2" class="data row4 col2" >5.4337</td>
#       <td id="T_a1224_row4_col3" class="data row4 col3" >2.2962</td>
#       <td id="T_a1224_row4_col4" class="data row4 col4" >0.9013</td>
#       <td id="T_a1224_row4_col5" class="data row4 col5" >0.3874</td>
#       <td id="T_a1224_row4_col6" class="data row4 col6" >3.7791</td>
#       <td id="T_a1224_row4_col7" class="data row4 col7" >9.4033</td>
#     </tr>
#     <tr>
#       <th id="T_a1224_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_a1224_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_a1224_row5_col1" class="data row5 col1" >1.3194</td>
#       <td id="T_a1224_row5_col2" class="data row5 col2" >5.8689</td>
#       <td id="T_a1224_row5_col3" class="data row5 col3
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]
# Best Model: ExtraTreesRegressor(n_jobs=-1, random_state=42)
# R² (Coefficient of Determination):   0.9139
# RMSE (Root Mean Squared Error):      2.2623
# MAE (Mean Absolute Error):           1.2496
# ρ (Pearson Correlation Coefficient): 0.9563
# ===================== [AutoML - NEE] =====================
# <style type="text/css">
# #T_48907_row8_col1, #T_48907_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_48907">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48907_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_48907_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48907_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48907_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_48907_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_48907_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_48907_row1_col1" class="data row1 col1" >NEE</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_48907_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_48907_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_48907_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_48907_row3_col1" class="data row3 col1" >(92046, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_48907_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_48907_row4_col1" class="data row4 col1" >(92046, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_48907_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_48907_row5_col1" class="data row5 col1" >(91953, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_48907_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_48907_row6_col1" class="data row6 col1" >(93, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_48907_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_48907_row7_col1" class="data row7 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_48907_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_48907_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_48907_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_48907_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_48907_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_48907_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_48907_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_48907_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_48907_row12_col0" class="data row12 col0" >Remove multicollinearity</td>
#       <td id="T_48907_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_48907_row13_col0" class="data row13 col0" >Multicollinearity threshold</td>
#       <td id="T_48907_row13_col1" class="data row13 col1" >0.950000</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_48907_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_48907_row14_col1" class="data row14 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_48907_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_48907_row15_col1" class="data row15 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_48907_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_48907_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_48907_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_48907_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_48907_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_48907_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_48907_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_48907_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_48907_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_48907_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_48907_row20_col1" class="data row20 col1" >0e37</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d9a9a th {
#   text-align: left;
# }
# #T_d9a9a_row0_col0, #T_d9a9a_row0_col5, #T_d9a9a_row0_col6, #T_d9a9a_row1_col0, #T_d9a9a_row1_col1, #T_d9a9a_row1_col2, #T_d9a9a_row1_col3, #T_d9a9a_row1_col4, #T_d9a9a_row1_col5, #T_d9a9a_row1_col6, #T_d9a9a_row2_col0, #T_d9a9a_row2_col1, #T_d9a9a_row2_col2, #T_d9a9a_row2_col3, #T_d9a9a_row2_col4, #T_d9a9a_row2_col5, #T_d9a9a_row3_col0, #T_d9a9a_row3_col1, #T_d9a9a_row3_col2, #T_d9a9a_row3_col3, #T_d9a9a_row3_col4, #T_d9a9a_row3_col5, #T_d9a9a_row3_col6, #T_d9a9a_row4_col0, #T_d9a9a_row4_col1, #T_d9a9a_row4_col2, #T_d9a9a_row4_col3, #T_d9a9a_row4_col4, #T_d9a9a_row4_col6, #T_d9a9a_row5_col0, #T_d9a9a_row5_col1, #T_d9a9a_row5_col2, #T_d9a9a_row5_col3, #T_d9a9a_row5_col4, #T_d9a9a_row5_col5, #T_d9a9a_row5_col6, #T_d9a9a_row6_col0, #T_d9a9a_row6_col1, #T_d9a9a_row6_col2, #T_d9a9a_row6_col3, #T_d9a9a_row6_col4, #T_d9a9a_row6_col5, #T_d9a9a_row6_col6, #T_d9a9a_row7_col0, #T_d9a9a_row7_col1, #T_d9a9a_row7_col2, #T_d9a9a_row7_col3, #T_d9a9a_row7_col4, #T_d9a9a_row7_col5, #T_d9a9a_row7_col6, #T_d9a9a_row8_col0, #T_d9a9a_row8_col1, #T_d9a9a_row8_col2, #T_d9a9a_row8_col3, #T_d9a9a_row8_col4, #T_d9a9a_row8_col5, #T_d9a9a_row8_col6, #T_d9a9a_row9_col0, #T_d9a9a_row9_col1, #T_d9a9a_row9_col2, #T_d9a9a_row9_col3, #T_d9a9a_row9_col4, #T_d9a9a_row9_col5, #T_d9a9a_row9_col6, #T_d9a9a_row10_col0, #T_d9a9a_row10_col1, #T_d9a9a_row10_col2, #T_d9a9a_row10_col3, #T_d9a9a_row10_col4, #T_d9a9a_row10_col5, #T_d9a9a_row10_col6, #T_d9a9a_row11_col0, #T_d9a9a_row11_col1, #T_d9a9a_row11_col2, #T_d9a9a_row11_col3, #T_d9a9a_row11_col4, #T_d9a9a_row11_col5, #T_d9a9a_row11_col6, #T_d9a9a_row12_col0, #T_d9a9a_row12_col1, #T_d9a9a_row12_col2, #T_d9a9a_row12_col3, #T_d9a9a_row12_col4, #T_d9a9a_row12_col5, #T_d9a9a_row12_col6, #T_d9a9a_row13_col0, #T_d9a9a_row13_col1, #T_d9a9a_row13_col2, #T_d9a9a_row13_col3, #T_d9a9a_row13_col4, #T_d9a9a_row13_col5, #T_d9a9a_row13_col6, #T_d9a9a_row14_col0, #T_d9a9a_row14_col1, #T_d9a9a_row14_col2, #T_d9a9a_row14_col3, #T_d9a9a_row14_col4, #T_d9a9a_row14_col5, #T_d9a9a_row14_col6, #T_d9a9a_row15_col0, #T_d9a9a_row15_col1, #T_d9a9a_row15_col2, #T_d9a9a_row15_col3, #T_d9a9a_row15_col4, #T_d9a9a_row15_col5, #T_d9a9a_row15_col6, #T_d9a9a_row16_col0, #T_d9a9a_row16_col1, #T_d9a9a_row16_col2, #T_d9a9a_row16_col3, #T_d9a9a_row16_col4, #T_d9a9a_row16_col5, #T_d9a9a_row16_col6, #T_d9a9a_row17_col0, #T_d9a9a_row17_col1, #T_d9a9a_row17_col2, #T_d9a9a_row17_col3, #T_d9a9a_row17_col4, #T_d9a9a_row17_col5, #T_d9a9a_row17_col6, #T_d9a9a_row18_col0, #T_d9a9a_row18_col1, #T_d9a9a_row18_col2, #T_d9a9a_row18_col3, #T_d9a9a_row18_col4, #T_d9a9a_row18_col5, #T_d9a9a_row18_col6, #T_d9a9a_row19_col0, #T_d9a9a_row19_col1, #T_d9a9a_row19_col2, #T_d9a9a_row19_col3, #T_d9a9a_row19_col4, #T_d9a9a_row19_col5, #T_d9a9a_row19_col6 {
#   text-align: left;
# }
# #T_d9a9a_row0_col1, #T_d9a9a_row0_col2, #T_d9a9a_row0_col3, #T_d9a9a_row0_col4, #T_d9a9a_row2_col6, #T_d9a9a_row4_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d9a9a_row0_col7, #T_d9a9a_row1_col7, #T_d9a9a_row2_col7, #T_d9a9a_row3_col7, #T_d9a9a_row4_col7, #T_d9a9a_row5_col7, #T_d9a9a_row6_col7, #T_d9a9a_row7_col7, #T_d9a9a_row8_col7, #T_d9a9a_row9_col7, #T_d9a9a_row11_col7, #T_d9a9a_row12_col7, #T_d9a9a_row13_col7, #T_d9a9a_row14_col7, #T_d9a9a_row15_col7, #T_d9a9a_row16_col7, #T_d9a9a_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d9a9a_row10_col7, #T_d9a9a_row17_col7, #T_d9a9a_row19_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d9a9a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9a9a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d9a9a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d9a9a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d9a9a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d9a9a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d9a9a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d9a9a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d9a9a_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9a9a_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_d9a9a_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_d9a9a_row0_col1" class="data row0 col1" >1.1638</td>
#       <td id="T_d9a9a_row0_col2" class="data row0 col2" >4.4570</td>
#       <td id="T_d9a9a_row0_col3" class="data row0 col3" >2.0804</td>
#       <td id="T_d9a9a_row0_col4" class="data row0 col4" >0.8903</td>
#       <td id="T_d9a9a_row0_col5" class="data row0 col5" >0.3398</td>
#       <td id="T_d9a9a_row0_col6" class="data row0 col6" >1.3268</td>
#       <td id="T_d9a9a_row0_col7" class="data row0 col7" >3.4400</td>
#     </tr>
#     <tr>
#       <th id="T_d9a9a_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_d9a9a_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_d9a9a_row1_col1" class="data row1 col1" >1.1833</td>
#       <td id="T_d9a9a_row1_col2" class="data row1 col2" >4.5786</td>
#       <td id="T_d9a9a_row1_col3" class="data row1 col3" >2.1105</td>
#       <td id="T_d9a9a_row1_col4" class="data row1 col4" >0.8870</td>
#       <td id="T_d9a9a_row1_col5" class="data row1 col5" >0.3489</td>
#       <td id="T_d9a9a_row1_col6" class="data row1 col6" >1.3463</td>
#       <td id="T_d9a9a_row1_col7" class="data row1 col7" >13.6233</td>
#     </tr>
#     <tr>
#       <th id="T_d9a9a_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_d9a9a_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d9a9a_row2_col1" class="data row2 col1" >1.1684</td>
#       <td id="T_d9a9a_row2_col2" class="data row2 col2" >4.6289</td>
#       <td id="T_d9a9a_row2_col3" class="data row2 col3" >2.1202</td>
#       <td id="T_d9a9a_row2_col4" class="data row2 col4" >0.8857</td>
#       <td id="T_d9a9a_row2_col5" class="data row2 col5" >0.3396</td>
#       <td id="T_d9a9a_row2_col6" class="data row2 col6" >1.2986</td>
#       <td id="T_d9a9a_row2_col7" class="data row2 col7" >4.4433</td>
#     </tr>
#     <tr>
#       <th id="T_d9a9a_level0_row3" class="row_heading level0 row3" >catboost</th>
#       <td id="T_d9a9a_row3_col0" class="data row3 col0" >CatBoost Regressor</td>
#       <td id="T_d9a9a_row3_col1" class="data row3 col1" >1.1759</td>
#       <td id="T_d9a9a_row3_col2" class="data row3 col2" >4.6568</td>
#       <td id="T_d9a9a_row3_col3" class="data row3 col3" >2.1251</td>
#       <td id="T_d9a9a_row3_col4" class="data row3 col4" >0.8849</td>
#       <td id="T_d9a9a_row3_col5" class="data row3 col5" >0.3400</td>
#       <td id="T_d9a9a_row3_col6" class="data row3 col6" >1.3352</td>
#       <td id="T_d9a9a_row3_col7" class="data row3 col7" >4.7333</td>
#     </tr>
#     <tr>
#       <th id="T_d9a9a_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_d9a9a_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_d9a9a_row4_col1" class="data row4 col1" >1.1818</td>
#       <td id="T_d9a9a_row4_col2" class="data row4 col2" >4.7378</td>
#       <td id="T_d9a9a_row4_col3" class="data row4 col3" >2.1477</td>
#       <td id="T_d9a9a_row4_col4" class="data row4 col4" >0.8830</td>
#       <td id="T_d9a9a_row4_col5" class="data row4 col5" >0.3376</td>
#       <td id="T_d9a9a_row4_col6" class="data row4 col6" >1.3372</td>
#       <td id="T_d9a9a_row4_col7" class="data row4 col7" >10.6933</td>
#     </tr>
#     <tr>
#       <th id="T_d9a9a_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_d9a9a_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_d9a9a_row5_col1" class="data row5 col1" >1.2454</td>
#       <td id="T_d9a9a_row5_col2" class="data row5 col2" >5.3381</td>
#       <td id="T_d9a9a_row5_col3" class="data
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]
# Best Model: ExtraTreesRegressor(n_jobs=-1, random_state=42)
# R² (Coefficient of Determination):   0.8944
# RMSE (Root Mean Squared Error):      2.1891
# MAE (Mean Absolute Error):           1.2406
# ρ (Pearson Correlation Coefficient): 0.9465
