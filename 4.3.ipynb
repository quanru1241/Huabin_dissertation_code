# %%
import pandas as pd
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from pycaret.regression import *
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from scipy.stats import pearsonr

# ========================== 1. Data loading ==========================

au_met = xr.open_dataset("AU-ASM/AU-ASM_2011-2017_OzFlux_Met.nc")
au_flux = xr.open_dataset("AU-ASM/AU-ASM_2011-2017_OzFlux_Flux.nc")

fi_met = xr.open_dataset("FI-Hyy/FI-Hyy_1996-2014_FLUXNET2015_Met.nc")
fi_flux = xr.open_dataset("FI-Hyy/FI-Hyy_1996-2014_FLUXNET2015_Flux.nc")

us_met = xr.open_dataset("US-UMB/US-UMB_2000-2014_FLUXNET2015_Met.nc")
us_flux = xr.open_dataset("US-UMB/US-UMB_2000-2014_FLUXNET2015_Flux.nc")

# ========================== 2. Feature definitions ==========================

features_raw = ['SWdown', 'LWdown', 'Tair', 'Qair', 'RH', 'Psurf', 'Wind',
                'CO2air', 'VPD', 'LAI', 'Ustar']
derived_features = ['SW_LAI', 'RH_Tair', 'SWdown_lag1', 'Tair_lag1']
geo_features = ['latitude', 'longitude']
target_var = 'GPP'

# ========================== 3. Preprocessing ==========================

def preprocess(met_ds, flux_ds, lat, lon):
    met_df = met_ds.to_dataframe().reset_index()
    flux_df = flux_ds.to_dataframe().reset_index()
    df = pd.merge_asof(met_df.sort_values('time'),
                       flux_df.sort_values('time'),
                       on='time')
    df = df[['time'] + features_raw + ['GPP', 'NEE']].dropna()

    # Derived features
    df['SW_LAI'] = df['SWdown'] * df['LAI']
    df['RH_Tair'] = df['RH'] * df['Tair']
    df['SWdown_lag1'] = df['SWdown'].shift(1)
    df['Tair_lag1'] = df['Tair'].shift(1)

    # Add site geolocation
    df['latitude'] = lat
    df['longitude'] = lon

    df = df.dropna().set_index('time').sort_index()
    return df

# ========================== 4. Build combined training data ==========================

df_au = preprocess(au_met, au_flux, lat=-22.283, lon=133.249)
df_fi = preprocess(fi_met, fi_flux, lat=61.85,  lon=24.3)
df_us = preprocess(us_met, us_flux, lat=45.55,  lon=-84.71)

df_all = pd.concat([df_au, df_fi, df_us], axis=0).reset_index(drop=True)
features_all = features_raw + derived_features + geo_features

# ========================== 5. AutoML training ==========================

s = setup(
    data=pd.concat([df_all[features_all], df_all[target_var]], axis=1),
    target=target_var,
    session_id=42,
    train_size=0.95,
    fold_strategy='timeseries',
    fold=3,
    fold_shuffle=False,
    data_split_shuffle=False,
    preprocess=True,
    numeric_features=features_all,
    remove_multicollinearity=True,
    multicollinearity_threshold=0.95,
    verbose=False
)

best_model = compare_models(sort='R2')

# ========================== 6. Site-wise generalization evaluation ==========================

def evaluate_site(df_site, name):
    test_X = df_site[features_all].reset_index(drop=True)
    test_y = df_site[target_var].reset_index(drop=True)

    preds = predict_model(best_model, data=test_X)
    y_pred = preds['prediction_label'].values
    y_true = test_y.values

    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae  = mean_absolute_error(y_true, y_pred)
    r2   = r2_score(y_true, y_pred)
    rho, _ = pearsonr(y_true, y_pred)

    print(f"\n🌍 Multi-site model evaluated at {name}:")
    print(f"R²:   {r2:.4f}")
    print(f"RMSE: {rmse:.4f}")
    print(f"MAE:  {mae:.4f}")
    print(f"ρ:    {rho:.4f}")

    # Visualization
    plt.figure(figsize=(12, 4))
    plt.plot(df_site.index, y_true, label="Observed",  alpha=0.7)
    plt.plot(df_site.index, y_pred, label="Predicted", alpha=0.7)
    plt.title(f"Multi-site model | {name} | {target_var} Prediction")
    plt.xlabel("Time")
    plt.ylabel(f"{target_var} (μmol m⁻² s⁻¹)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

evaluate_site(df_au, "AU-ASM")
evaluate_site(df_fi, "FI-Hyy")
evaluate_site(df_us, "US-UMB")
# Out:
# <style type="text/css">
# #T_f6de7 th {
#   text-align: left;
# }
# #T_f6de7_row0_col0, #T_f6de7_row0_col5, #T_f6de7_row0_col6, #T_f6de7_row1_col0, #T_f6de7_row1_col1, #T_f6de7_row1_col2, #T_f6de7_row1_col3, #T_f6de7_row1_col4, #T_f6de7_row1_col5, #T_f6de7_row2_col0, #T_f6de7_row2_col1, #T_f6de7_row2_col2, #T_f6de7_row2_col3, #T_f6de7_row2_col4, #T_f6de7_row2_col5, #T_f6de7_row2_col6, #T_f6de7_row3_col0, #T_f6de7_row3_col1, #T_f6de7_row3_col2, #T_f6de7_row3_col3, #T_f6de7_row3_col4, #T_f6de7_row3_col6, #T_f6de7_row4_col0, #T_f6de7_row4_col1, #T_f6de7_row4_col2, #T_f6de7_row4_col3, #T_f6de7_row4_col4, #T_f6de7_row4_col5, #T_f6de7_row4_col6, #T_f6de7_row5_col0, #T_f6de7_row5_col1, #T_f6de7_row5_col2, #T_f6de7_row5_col3, #T_f6de7_row5_col4, #T_f6de7_row5_col5, #T_f6de7_row5_col6, #T_f6de7_row6_col0, #T_f6de7_row6_col1, #T_f6de7_row6_col2, #T_f6de7_row6_col3, #T_f6de7_row6_col4, #T_f6de7_row6_col5, #T_f6de7_row6_col6, #T_f6de7_row7_col0, #T_f6de7_row7_col1, #T_f6de7_row7_col2, #T_f6de7_row7_col3, #T_f6de7_row7_col4, #T_f6de7_row7_col5, #T_f6de7_row7_col6, #T_f6de7_row8_col0, #T_f6de7_row8_col1, #T_f6de7_row8_col2, #T_f6de7_row8_col3, #T_f6de7_row8_col4, #T_f6de7_row8_col5, #T_f6de7_row8_col6, #T_f6de7_row9_col0, #T_f6de7_row9_col1, #T_f6de7_row9_col2, #T_f6de7_row9_col3, #T_f6de7_row9_col4, #T_f6de7_row9_col5, #T_f6de7_row9_col6, #T_f6de7_row10_col0, #T_f6de7_row10_col1, #T_f6de7_row10_col2, #T_f6de7_row10_col3, #T_f6de7_row10_col4, #T_f6de7_row10_col5, #T_f6de7_row10_col6, #T_f6de7_row11_col0, #T_f6de7_row11_col1, #T_f6de7_row11_col2, #T_f6de7_row11_col3, #T_f6de7_row11_col4, #T_f6de7_row11_col5, #T_f6de7_row11_col6, #T_f6de7_row12_col0, #T_f6de7_row12_col1, #T_f6de7_row12_col2, #T_f6de7_row12_col3, #T_f6de7_row12_col4, #T_f6de7_row12_col5, #T_f6de7_row12_col6, #T_f6de7_row13_col0, #T_f6de7_row13_col1, #T_f6de7_row13_col2, #T_f6de7_row13_col3, #T_f6de7_row13_col4, #T_f6de7_row13_col5, #T_f6de7_row13_col6, #T_f6de7_row14_col0, #T_f6de7_row14_col1, #T_f6de7_row14_col2, #T_f6de7_row14_col3, #T_f6de7_row14_col4, #T_f6de7_row14_col5, #T_f6de7_row14_col6, #T_f6de7_row15_col0, #T_f6de7_row15_col1, #T_f6de7_row15_col2, #T_f6de7_row15_col3, #T_f6de7_row15_col4, #T_f6de7_row15_col5, #T_f6de7_row15_col6, #T_f6de7_row16_col0, #T_f6de7_row16_col1, #T_f6de7_row16_col2, #T_f6de7_row16_col3, #T_f6de7_row16_col4, #T_f6de7_row16_col5, #T_f6de7_row16_col6, #T_f6de7_row17_col0, #T_f6de7_row17_col1, #T_f6de7_row17_col2, #T_f6de7_row17_col3, #T_f6de7_row17_col4, #T_f6de7_row17_col5, #T_f6de7_row17_col6, #T_f6de7_row18_col0, #T_f6de7_row18_col1, #T_f6de7_row18_col2, #T_f6de7_row18_col3, #T_f6de7_row18_col4, #T_f6de7_row18_col5, #T_f6de7_row18_col6, #T_f6de7_row19_col0, #T_f6de7_row19_col1, #T_f6de7_row19_col2, #T_f6de7_row19_col3, #T_f6de7_row19_col4, #T_f6de7_row19_col5, #T_f6de7_row19_col6 {
#   text-align: left;
# }
# #T_f6de7_row0_col1, #T_f6de7_row0_col2, #T_f6de7_row0_col3, #T_f6de7_row0_col4, #T_f6de7_row1_col6, #T_f6de7_row3_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f6de7_row0_col7, #T_f6de7_row1_col7, #T_f6de7_row2_col7, #T_f6de7_row3_col7, #T_f6de7_row4_col7, #T_f6de7_row5_col7, #T_f6de7_row6_col7, #T_f6de7_row7_col7, #T_f6de7_row8_col7, #T_f6de7_row9_col7, #T_f6de7_row10_col7, #T_f6de7_row11_col7, #T_f6de7_row12_col7, #T_f6de7_row13_col7, #T_f6de7_row14_col7, #T_f6de7_row15_col7, #T_f6de7_row16_col7, #T_f6de7_row17_col7, #T_f6de7_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f6de7_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f6de7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6de7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f6de7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f6de7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f6de7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f6de7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f6de7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f6de7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f6de7_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6de7_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_f6de7_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_f6de7_row0_col1" class="data row0 col1" >1.1756</td>
#       <td id="T_f6de7_row0_col2" class="data row0 col2" >4.7580</td>
#       <td id="T_f6de7_row0_col3" class="data row0 col3" >2.1447</td>
#       <td id="T_f6de7_row0_col4" class="data row0 col4" >0.8490</td>
#       <td id="T_f6de7_row0_col5" class="data row0 col5" >0.3852</td>
#       <td id="T_f6de7_row0_col6" class="data row0 col6" >4.2196</td>
#       <td id="T_f6de7_row0_col7" class="data row0 col7" >35.1567</td>
#     </tr>
#     <tr>
#       <th id="T_f6de7_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_f6de7_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f6de7_row1_col1" class="data row1 col1" >1.1910</td>
#       <td id="T_f6de7_row1_col2" class="data row1 col2" >5.0384</td>
#       <td id="T_f6de7_row1_col3" class="data row1 col3" >2.1961</td>
#       <td id="T_f6de7_row1_col4" class="data row1 col4" >0.8387</td>
#       <td id="T_f6de7_row1_col5" class="data row1 col5" >0.3976</td>
#       <td id="T_f6de7_row1_col6" class="data row1 col6" >3.8379</td>
#       <td id="T_f6de7_row1_col7" class="data row1 col7" >1.1433</td>
#     </tr>
#     <tr>
#       <th id="T_f6de7_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_f6de7_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_f6de7_row2_col1" class="data row2 col1" >1.2181</td>
#       <td id="T_f6de7_row2_col2" class="data row2 col2" >5.1023</td>
#       <td id="T_f6de7_row2_col3" class="data row2 col3" >2.2135</td>
#       <td id="T_f6de7_row2_col4" class="data row2 col4" >0.8384</td>
#       <td id="T_f6de7_row2_col5" class="data row2 col5" >0.3908</td>
#       <td id="T_f6de7_row2_col6" class="data row2 col6" >4.8107</td>
#       <td id="T_f6de7_row2_col7" class="data row2 col7" >7.4267</td>
#     </tr>
#     <tr>
#       <th id="T_f6de7_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_f6de7_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_f6de7_row3_col1" class="data row3 col1" >1.1928</td>
#       <td id="T_f6de7_row3_col2" class="data row3 col2" >5.0473</td>
#       <td id="T_f6de7_row3_col3" class="data row3 col3" >2.1912</td>
#       <td id="T_f6de7_row3_col4" class="data row3 col4" >0.8374</td>
#       <td id="T_f6de7_row3_col5" class="data row3 col5" >0.3796</td>
#       <td id="T_f6de7_row3_col6" class="data row3 col6" >4.9544</td>
#       <td id="T_f6de7_row3_col7" class="data row3 col7" >15.4067</td>
#     </tr>
#     <tr>
#       <th id="T_f6de7_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_f6de7_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_f6de7_row4_col1" class="data row4 col1" >1.2314</td>
#       <td id="T_f6de7_row4_col2" class="data row4 col2" >5.2784</td>
#       <td id="T_f6de7_row4_col3" class="data row4 col3" >2.2414</td>
#       <td id="T_f6de7_row4_col4" class="data row4 col4" >0.8290</td>
#       <td id="T_f6de7_row4_col5" class="data row4 col5" >0.3946</td>
#       <td id="T_f6de7_row4_col6" class="data row4 col6" >4.8865</td>
#       <td id="T_f6de7_row4_col7" class="data row4 col7" >0.6567</td>
#     </tr>
#     <tr>
#       <th id="T_f6de7_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_f6de7_row5_col0" class="data row5 col0" >Random Forest Regressor</td>
#       <td id="T_f6de7_row5_col1" class="data row5 col1" >1.2261</td>
#       <td id="T_f6de7_row5_col2" class="data row5 col2" >5.3570</td>
#       <td id="T_f6de7_row5_col3" class="data
# 🌍 Multi-site model evaluated at AU-ASM:
# R²:   0.6932
# RMSE: 1.0833
# MAE:  0.5431
# ρ:    0.8352
# 🌍 Multi-site model evaluated at FI-Hyy:
# R²:   0.9266
# RMSE: 1.4307
# MAE:  0.8420
# ρ:    0.9626
# 🌍 Multi-site model evaluated at US-UMB:
# R²:   0.9099
# RMSE: 2.1884
# MAE:  1.2056
# ρ:    0.9540

# %%
import pandas as pd
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from pycaret.regression import *
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from scipy.stats import pearsonr

# ========================== 1. Data loading ==========================

au_met = xr.open_dataset("AU-ASM/AU-ASM_2011-2017_OzFlux_Met.nc")
au_flux = xr.open_dataset("AU-ASM/AU-ASM_2011-2017_OzFlux_Flux.nc")

fi_met = xr.open_dataset("FI-Hyy/FI-Hyy_1996-2014_FLUXNET2015_Met.nc")
fi_flux = xr.open_dataset("FI-Hyy/FI-Hyy_1996-2014_FLUXNET2015_Flux.nc")

us_met = xr.open_dataset("US-UMB/US-UMB_2000-2014_FLUXNET2015_Met.nc")
us_flux = xr.open_dataset("US-UMB/US-UMB_2000-2014_FLUXNET2015_Flux.nc")

# ========================== 2. Feature definitions ==========================

features_raw = ['SWdown', 'LWdown', 'Tair', 'Qair', 'RH', 'Psurf', 'Wind',
                'CO2air', 'VPD', 'LAI', 'Ustar']
derived_features = ['SW_LAI', 'RH_Tair', 'SWdown_lag1', 'Tair_lag1']
geo_features = ['latitude', 'longitude']
target_var = 'NEE'

# ========================== 3. Preprocessing ==========================

def preprocess(met_ds, flux_ds, lat, lon):
    met_df = met_ds.to_dataframe().reset_index()
    flux_df = flux_ds.to_dataframe().reset_index()
    df = pd.merge_asof(met_df.sort_values('time'),
                       flux_df.sort_values('time'),
                       on='time')
    df = df[['time'] + features_raw + ['GPP', 'NEE']].dropna()

    # Derived features
    df['SW_LAI'] = df['SWdown'] * df['LAI']
    df['RH_Tair'] = df['RH'] * df['Tair']
    df['SWdown_lag1'] = df['SWdown'].shift(1)
    df['Tair_lag1'] = df['Tair'].shift(1)

    # Add site geolocation
    df['latitude'] = lat
    df['longitude'] = lon

    df = df.dropna().set_index('time').sort_index()
    return df

# ========================== 4. Build combined training data ==========================

df_au = preprocess(au_met, au_flux, lat=-22.283, lon=133.249)
df_fi = preprocess(fi_met, fi_flux, lat=61.85,  lon=24.3)
df_us = preprocess(us_met, us_flux, lat=45.55,  lon=-84.71)

df_all = pd.concat([df_au, df_fi, df_us], axis=0).reset_index(drop=True)
features_all = features_raw + derived_features + geo_features

# ========================== 5. AutoML training ==========================

s = setup(
    data=pd.concat([df_all[features_all], df_all[target_var]], axis=1),
    target=target_var,
    session_id=42,
    train_size=0.95,
    fold_strategy='timeseries',
    fold=3,
    fold_shuffle=False,
    data_split_shuffle=False,
    preprocess=True,
    numeric_features=features_all,
    remove_multicollinearity=True,
    multicollinearity_threshold=0.95,
    verbose=False
)

best_model = compare_models(sort='R2')

# ========================== 6. Site-wise generalization evaluation ==========================

def evaluate_site(df_site, name):
    test_X = df_site[features_all].reset_index(drop=True)
    test_y = df_site[target_var].reset_index(drop=True)
    preds = predict_model(best_model, data=test_X)
    y_pred = preds['prediction_label'].values
    y_true = test_y.values

    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae  = mean_absolute_error(y_true, y_pred)
    r2   = r2_score(y_true, y_pred)
    rho, _ = pearsonr(y_true, y_pred)

    print(f"\n🌍 Multi-site model evaluated at {name}:")
    print(f"R²:   {r2:.4f}")
    print(f"RMSE: {rmse:.4f}")
    print(f"MAE:  {mae:.4f}")
    print(f"ρ:    {rho:.4f}")

    # Visualization
    plt.figure(figsize=(12, 4))
    plt.plot(df_site.index, y_true, label="Observed",  alpha=0.7)
    plt.plot(df_site.index, y_pred, label="Predicted", alpha=0.7)
    plt.title(f"Multi-site model | {name} | {target_var} Prediction")
    plt.xlabel("Time")
    plt.ylabel(f"{target_var} (μmol m⁻² s⁻¹)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

evaluate_site(df_au, "AU-ASM")
evaluate_site(df_fi, "FI-Hyy")
evaluate_site(df_us, "US-UMB")
# Out:
# <style type="text/css">
# #T_9f19a th {
#   text-align: left;
# }
# #T_9f19a_row0_col0, #T_9f19a_row0_col1, #T_9f19a_row0_col3, #T_9f19a_row0_col5, #T_9f19a_row0_col6, #T_9f19a_row1_col0, #T_9f19a_row1_col1, #T_9f19a_row1_col2, #T_9f19a_row1_col4, #T_9f19a_row1_col5, #T_9f19a_row1_col6, #T_9f19a_row2_col0, #T_9f19a_row2_col2, #T_9f19a_row2_col3, #T_9f19a_row2_col4, #T_9f19a_row2_col5, #T_9f19a_row2_col6, #T_9f19a_row3_col0, #T_9f19a_row3_col1, #T_9f19a_row3_col2, #T_9f19a_row3_col3, #T_9f19a_row3_col4, #T_9f19a_row3_col6, #T_9f19a_row4_col0, #T_9f19a_row4_col1, #T_9f19a_row4_col2, #T_9f19a_row4_col3, #T_9f19a_row4_col4, #T_9f19a_row4_col5, #T_9f19a_row4_col6, #T_9f19a_row5_col0, #T_9f19a_row5_col1, #T_9f19a_row5_col2, #T_9f19a_row5_col3, #T_9f19a_row5_col4, #T_9f19a_row5_col5, #T_9f19a_row5_col6, #T_9f19a_row6_col0, #T_9f19a_row6_col1, #T_9f19a_row6_col2, #T_9f19a_row6_col3, #T_9f19a_row6_col4, #T_9f19a_row6_col5, #T_9f19a_row6_col6, #T_9f19a_row7_col0, #T_9f19a_row7_col1, #T_9f19a_row7_col2, #T_9f19a_row7_col3, #T_9f19a_row7_col4, #T_9f19a_row7_col5, #T_9f19a_row7_col6, #T_9f19a_row8_col0, #T_9f19a_row8_col1, #T_9f19a_row8_col2, #T_9f19a_row8_col3, #T_9f19a_row8_col4, #T_9f19a_row8_col5, #T_9f19a_row8_col6, #T_9f19a_row9_col0, #T_9f19a_row9_col1, #T_9f19a_row9_col2, #T_9f19a_row9_col3, #T_9f19a_row9_col4, #T_9f19a_row9_col5, #T_9f19a_row9_col6, #T_9f19a_row10_col0, #T_9f19a_row10_col1, #T_9f19a_row10_col2, #T_9f19a_row10_col3, #T_9f19a_row10_col4, #T_9f19a_row10_col5, #T_9f19a_row10_col6, #T_9f19a_row11_col0, #T_9f19a_row11_col1, #T_9f19a_row11_col2, #T_9f19a_row11_col3, #T_9f19a_row11_col4, #T_9f19a_row11_col5, #T_9f19a_row11_col6, #T_9f19a_row12_col0, #T_9f19a_row12_col1, #T_9f19a_row12_col2, #T_9f19a_row12_col3, #T_9f19a_row12_col4, #T_9f19a_row12_col5, #T_9f19a_row12_col6, #T_9f19a_row13_col0, #T_9f19a_row13_col1, #T_9f19a_row13_col2, #T_9f19a_row13_col3, #T_9f19a_row13_col4, #T_9f19a_row13_col5, #T_9f19a_row13_col6, #T_9f19a_row14_col0, #T_9f19a_row14_col1, #T_9f19a_row14_col2, #T_9f19a_row14_col3, #T_9f19a_row14_col4, #T_9f19a_row14_col5, #T_9f19a_row14_col6, #T_9f19a_row15_col0, #T_9f19a_row15_col1, #T_9f19a_row15_col2, #T_9f19a_row15_col3, #T_9f19a_row15_col4, #T_9f19a_row15_col5, #T_9f19a_row15_col6, #T_9f19a_row16_col0, #T_9f19a_row16_col1, #T_9f19a_row16_col2, #T_9f19a_row16_col3, #T_9f19a_row16_col4, #T_9f19a_row16_col5, #T_9f19a_row16_col6, #T_9f19a_row17_col0, #T_9f19a_row17_col1, #T_9f19a_row17_col2, #T_9f19a_row17_col3, #T_9f19a_row17_col4, #T_9f19a_row17_col5, #T_9f19a_row17_col6, #T_9f19a_row18_col0, #T_9f19a_row18_col1, #T_9f19a_row18_col2, #T_9f19a_row18_col3, #T_9f19a_row18_col4, #T_9f19a_row18_col5, #T_9f19a_row18_col6, #T_9f19a_row19_col0, #T_9f19a_row19_col1, #T_9f19a_row19_col2, #T_9f19a_row19_col3, #T_9f19a_row19_col4, #T_9f19a_row19_col5 {
#   text-align: left;
# }
# #T_9f19a_row0_col2, #T_9f19a_row0_col4, #T_9f19a_row1_col3, #T_9f19a_row2_col1, #T_9f19a_row3_col5, #T_9f19a_row19_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_9f19a_row0_col7, #T_9f19a_row1_col7, #T_9f19a_row2_col7, #T_9f19a_row3_col7, #T_9f19a_row4_col7, #T_9f19a_row5_col7, #T_9f19a_row6_col7, #T_9f19a_row7_col7, #T_9f19a_row8_col7, #T_9f19a_row9_col7, #T_9f19a_row10_col7, #T_9f19a_row11_col7, #T_9f19a_row12_col7, #T_9f19a_row13_col7, #T_9f19a_row14_col7, #T_9f19a_row15_col7, #T_9f19a_row16_col7, #T_9f19a_row17_col7, #T_9f19a_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_9f19a_row19_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_9f19a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f19a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9f19a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9f19a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9f19a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9f19a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9f19a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9f19a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_9f19a_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f19a_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_9f19a_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_9f19a_row0_col1" class="data row0 col1" >1.1976</td>
#       <td id="T_9f19a_row0_col2" class="data row0 col2" >4.1034</td>
#       <td id="T_9f19a_row0_col3" class="data row0 col3" >1.9928</td>
#       <td id="T_9f19a_row0_col4" class="data row0 col4" >0.8151</td>
#       <td id="T_9f19a_row0_col5" class="data row0 col5" >0.3987</td>
#       <td id="T_9f19a_row0_col6" class="data row0 col6" >2.5931</td>
#       <td id="T_9f19a_row0_col7" class="data row0 col7" >33.6567</td>
#     </tr>
#     <tr>
#       <th id="T_9f19a_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_9f19a_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_9f19a_row1_col1" class="data row1 col1" >1.1765</td>
#       <td id="T_9f19a_row1_col2" class="data row1 col2" >4.1231</td>
#       <td id="T_9f19a_row1_col3" class="data row1 col3" >1.9897</td>
#       <td id="T_9f19a_row1_col4" class="data row1 col4" >0.8140</td>
#       <td id="T_9f19a_row1_col5" class="data row1 col5" >0.3962</td>
#       <td id="T_9f19a_row1_col6" class="data row1 col6" >2.2685</td>
#       <td id="T_9f19a_row1_col7" class="data row1 col7" >0.8800</td>
#     </tr>
#     <tr>
#       <th id="T_9f19a_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_9f19a_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_9f19a_row2_col1" class="data row2 col1" >1.1758</td>
#       <td id="T_9f19a_row2_col2" class="data row2 col2" >4.1460</td>
#       <td id="T_9f19a_row2_col3" class="data row2 col3" >1.9993</td>
#       <td id="T_9f19a_row2_col4" class="data row2 col4" >0.8130</td>
#       <td id="T_9f19a_row2_col5" class="data row2 col5" >0.3879</td>
#       <td id="T_9f19a_row2_col6" class="data row2 col6" >2.2891</td>
#       <td id="T_9f19a_row2_col7" class="data row2 col7" >5.2133</td>
#     </tr>
#     <tr>
#       <th id="T_9f19a_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_9f19a_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_9f19a_row3_col1" class="data row3 col1" >1.1793</td>
#       <td id="T_9f19a_row3_col2" class="data row3 col2" >4.3080</td>
#       <td id="T_9f19a_row3_col3" class="data row3 col3" >2.0276</td>
#       <td id="T_9f19a_row3_col4" class="data row3 col4" >0.8038</td>
#       <td id="T_9f19a_row3_col5" class="data row3 col5" >0.3867</td>
#       <td id="T_9f19a_row3_col6" class="data row3 col6" >2.2414</td>
#       <td id="T_9f19a_row3_col7" class="data row3 col7" >11.0400</td>
#     </tr>
#     <tr>
#       <th id="T_9f19a_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_9f19a_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_9f19a_row4_col1" class="data row4 col1" >1.2520</td>
#       <td id="T_9f19a_row4_col2" class="data row4 col2" >4.4390</td>
#       <td id="T_9f19a_row4_col3" class="data row4 col3" >2.0629</td>
#       <td id="T_9f19a_row4_col4" class="data row4 col4" >0.7989</td>
#       <td id="T_9f19a_row4_col5" class="data row4 col5" >0.4106</td>
#       <td id="T_9f19a_row4_col6" class="data row4 col6" >2.4756</td>
#       <td id="T_9f19a_row4_col7" class="data row4 col7" >0.7900</td>
#     </tr>
#     <tr>
#       <th id="T_9f19a_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_9f19a_row5_col0" class="data row5 col0" >Random Forest Regressor</td>
#       <td id="T_9f19a_row5_col1" class="data row5 col1" >1.2345</td>
#       <td id="T_9f19a_row5_col2" class="data row5 col2" >4.4898</td>
#       <td id="T_9f19a_row5_col3" class="data
# 🌍 Multi-site model evaluated at AU-ASM:
# R²:   0.6355
# RMSE: 1.1240
# MAE:  0.7092
# ρ:    0.8013
# 🌍 Multi-site model evaluated at FI-Hyy:
# R²:   0.8986
# RMSE: 1.3759
# MAE:  0.8709
# ρ:    0.9481
# 🌍 Multi-site model evaluated at US-UMB:
# R²:   0.8869
# RMSE: 2.1109
# MAE:  1.2033
# ρ:    0.9420
