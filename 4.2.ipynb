# %% [markdown]
# ## AU-ASM → FI-Hyy Transfer

# %%
import pandas as pd
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from pycaret.regression import *
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from scipy.stats import pearsonr

# ========================== 1. Site paths ==========================

# AU-ASM training data
au_met = xr.open_dataset("AU-ASM/AU-ASM_2011-2017_OzFlux_Met.nc")
au_flux = xr.open_dataset("AU-ASM/AU-ASM_2011-2017_OzFlux_Flux.nc")

# FI-Hyy test data (adjust paths as needed)
fi_met = xr.open_dataset("FI-Hyy/FI-Hyy_1996-2014_FLUXNET2015_Met.nc")
fi_flux = xr.open_dataset("FI-Hyy/FI-Hyy_1996-2014_FLUXNET2015_Flux.nc")

# ========================== 2. Feature definitions ==========================

features_raw = ['SWdown', 'LWdown', 'Tair', 'Qair', 'RH', 'Psurf', 'Wind',
                'CO2air', 'VPD', 'LAI', 'Ustar']
derived_features = ['SW_LAI', 'RH_Tair', 'SWdown_lag1', 'Tair_lag1']
target_var = 'NEE'  # or 'GPP'

# ========================== 3. Preprocessing ==========================

def preprocess(met_ds, flux_ds):
    met_df = met_ds.to_dataframe().reset_index()
    flux_df = flux_ds.to_dataframe().reset_index()
    df = pd.merge_asof(met_df.sort_values('time'),
                       flux_df.sort_values('time'),
                       on='time')
    df = df[['time'] + features_raw + ['GPP', 'NEE']].dropna()

    # Derived features
    df['SW_LAI'] = df['SWdown'] * df['LAI']
    df['RH_Tair'] = df['RH'] * df['Tair']
    df['SWdown_lag1'] = df['SWdown'].shift(1)
    df['Tair_lag1'] = df['Tair'].shift(1)

    df = df.dropna().set_index('time').sort_index()
    return df

# ========================== 4. Build train/test data ==========================

df_train = preprocess(au_met, au_flux)
df_test = preprocess(fi_met, fi_flux)

features_all = features_raw + derived_features

# ========================== 5. AutoML training (AU-ASM only) ==========================

train_data = pd.concat([df_train[features_all], df_train[target_var]], axis=1).reset_index(drop=True)

s = setup(
    data=train_data,
    target=target_var,
    session_id=42,
    train_size=0.999,
    fold_strategy='timeseries',
    fold=3,
    fold_shuffle=False,
    data_split_shuffle=False,
    preprocess=True,
    numeric_features=features_all,
    remove_multicollinearity=True,
    multicollinearity_threshold=0.95,
    verbose=False
)

best_model = compare_models(sort='R2')

# ========================== 6. Transfer evaluation (on FI-Hyy) ==========================

test_data = df_test[features_all].reset_index(drop=True)
true_vals = df_test[target_var].reset_index(drop=True)

preds = predict_model(best_model, data=test_data)
y_pred = preds['prediction_label'].values
y_true = true_vals.values

# ========================== 7. Metrics ==========================

rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mae = mean_absolute_error(y_true, y_pred)
r2 = r2_score(y_true, y_pred)
rho, _ = pearsonr(y_true, y_pred)

print(f"\n🔍 AU-ASM → FI-Hyy transfer results for {target_var}:")
print(f"Best model: {best_model}")
print(f"R²:   {r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"ρ:    {rho:.4f}")

# ========================== 8. Visualization: time series comparison ==========================

plt.figure(figsize=(12, 4))
plt.plot(df_test.index, y_true, label="Observed", alpha=0.7)
plt.plot(df_test.index, y_pred, label="Predicted", alpha=0.7)
plt.title(f"AU-ASM → FI-Hyy Transfer | {target_var} Prediction")
plt.xlabel("Time")
plt.ylabel(f"{target_var} (μmol m⁻² s⁻¹)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# #T_0a4a3 th {
#   text-align: left;
# }
# #T_0a4a3_row0_col0, #T_0a4a3_row0_col1, #T_0a4a3_row0_col5, #T_0a4a3_row0_col6, #T_0a4a3_row1_col0, #T_0a4a3_row1_col1, #T_0a4a3_row1_col2, #T_0a4a3_row1_col3, #T_0a4a3_row1_col4, #T_0a4a3_row1_col5, #T_0a4a3_row1_col6, #T_0a4a3_row2_col0, #T_0a4a3_row2_col2, #T_0a4a3_row2_col3, #T_0a4a3_row2_col4, #T_0a4a3_row3_col0, #T_0a4a3_row3_col1, #T_0a4a3_row3_col2, #T_0a4a3_row3_col3, #T_0a4a3_row3_col4, #T_0a4a3_row3_col5, #T_0a4a3_row3_col6, #T_0a4a3_row4_col0, #T_0a4a3_row4_col1, #T_0a4a3_row4_col2, #T_0a4a3_row4_col3, #T_0a4a3_row4_col4, #T_0a4a3_row4_col5, #T_0a4a3_row4_col6, #T_0a4a3_row5_col0, #T_0a4a3_row5_col1, #T_0a4a3_row5_col2, #T_0a4a3_row5_col3, #T_0a4a3_row5_col4, #T_0a4a3_row5_col5, #T_0a4a3_row5_col6, #T_0a4a3_row6_col0, #T_0a4a3_row6_col1, #T_0a4a3_row6_col2, #T_0a4a3_row6_col3, #T_0a4a3_row6_col4, #T_0a4a3_row6_col5, #T_0a4a3_row6_col6, #T_0a4a3_row7_col0, #T_0a4a3_row7_col1, #T_0a4a3_row7_col2, #T_0a4a3_row7_col3, #T_0a4a3_row7_col4, #T_0a4a3_row7_col5, #T_0a4a3_row7_col6, #T_0a4a3_row8_col0, #T_0a4a3_row8_col1, #T_0a4a3_row8_col2, #T_0a4a3_row8_col3, #T_0a4a3_row8_col4, #T_0a4a3_row8_col5, #T_0a4a3_row8_col6, #T_0a4a3_row9_col0, #T_0a4a3_row9_col1, #T_0a4a3_row9_col2, #T_0a4a3_row9_col3, #T_0a4a3_row9_col4, #T_0a4a3_row9_col5, #T_0a4a3_row9_col6, #T_0a4a3_row10_col0, #T_0a4a3_row10_col1, #T_0a4a3_row10_col2, #T_0a4a3_row10_col3, #T_0a4a3_row10_col4, #T_0a4a3_row10_col5, #T_0a4a3_row10_col6, #T_0a4a3_row11_col0, #T_0a4a3_row11_col1, #T_0a4a3_row11_col2, #T_0a4a3_row11_col3, #T_0a4a3_row11_col4, #T_0a4a3_row11_col5, #T_0a4a3_row11_col6, #T_0a4a3_row12_col0, #T_0a4a3_row12_col1, #T_0a4a3_row12_col2, #T_0a4a3_row12_col3, #T_0a4a3_row12_col4, #T_0a4a3_row12_col5, #T_0a4a3_row12_col6, #T_0a4a3_row13_col0, #T_0a4a3_row13_col1, #T_0a4a3_row13_col2, #T_0a4a3_row13_col3, #T_0a4a3_row13_col4, #T_0a4a3_row13_col5, #T_0a4a3_row13_col6, #T_0a4a3_row14_col0, #T_0a4a3_row14_col1, #T_0a4a3_row14_col2, #T_0a4a3_row14_col3, #T_0a4a3_row14_col4, #T_0a4a3_row14_col5, #T_0a4a3_row14_col6, #T_0a4a3_row15_col0, #T_0a4a3_row15_col1, #T_0a4a3_row15_col2, #T_0a4a3_row15_col3, #T_0a4a3_row15_col4, #T_0a4a3_row15_col5, #T_0a4a3_row15_col6, #T_0a4a3_row16_col0, #T_0a4a3_row16_col1, #T_0a4a3_row16_col2, #T_0a4a3_row16_col3, #T_0a4a3_row16_col4, #T_0a4a3_row16_col5, #T_0a4a3_row16_col6, #T_0a4a3_row17_col0, #T_0a4a3_row17_col1, #T_0a4a3_row17_col2, #T_0a4a3_row17_col3, #T_0a4a3_row17_col4, #T_0a4a3_row17_col5, #T_0a4a3_row17_col6, #T_0a4a3_row18_col0, #T_0a4a3_row18_col1, #T_0a4a3_row18_col2, #T_0a4a3_row18_col3, #T_0a4a3_row18_col4, #T_0a4a3_row18_col5, #T_0a4a3_row18_col6, #T_0a4a3_row19_col0, #T_0a4a3_row19_col1, #T_0a4a3_row19_col2, #T_0a4a3_row19_col3, #T_0a4a3_row19_col4, #T_0a4a3_row19_col5, #T_0a4a3_row19_col6 {
#   text-align: left;
# }
# #T_0a4a3_row0_col2, #T_0a4a3_row0_col3, #T_0a4a3_row0_col4, #T_0a4a3_row2_col1, #T_0a4a3_row2_col5, #T_0a4a3_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0a4a3_row0_col7, #T_0a4a3_row1_col7, #T_0a4a3_row2_col7, #T_0a4a3_row3_col7, #T_0a4a3_row4_col7, #T_0a4a3_row5_col7, #T_0a4a3_row6_col7, #T_0a4a3_row7_col7, #T_0a4a3_row8_col7, #T_0a4a3_row9_col7, #T_0a4a3_row10_col7, #T_0a4a3_row11_col7, #T_0a4a3_row12_col7, #T_0a4a3_row13_col7, #T_0a4a3_row14_col7, #T_0a4a3_row15_col7, #T_0a4a3_row16_col7, #T_0a4a3_row18_col7, #T_0a4a3_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0a4a3_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0a4a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a4a3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0a4a3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0a4a3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0a4a3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0a4a3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0a4a3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0a4a3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_0a4a3_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a4a3_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_0a4a3_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_0a4a3_row0_col1" class="data row0 col1" >0.5753</td>
#       <td id="T_0a4a3_row0_col2" class="data row0 col2" >1.2624</td>
#       <td id="T_0a4a3_row0_col3" class="data row0 col3" >1.0940</td>
#       <td id="T_0a4a3_row0_col4" class="data row0 col4" >0.6039</td>
#       <td id="T_0a4a3_row0_col5" class="data row0 col5" >0.3190</td>
#       <td id="T_0a4a3_row0_col6" class="data row0 col6" >2.5030</td>
#       <td id="T_0a4a3_row0_col7" class="data row0 col7" >8.1033</td>
#     </tr>
#     <tr>
#       <th id="T_0a4a3_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_0a4a3_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_0a4a3_row1_col1" class="data row1 col1" >0.5630</td>
#       <td id="T_0a4a3_row1_col2" class="data row1 col2" >1.3772</td>
#       <td id="T_0a4a3_row1_col3" class="data row1 col3" >1.1356</td>
#       <td id="T_0a4a3_row1_col4" class="data row1 col4" >0.5826</td>
#       <td id="T_0a4a3_row1_col5" class="data row1 col5" >0.3135</td>
#       <td id="T_0a4a3_row1_col6" class="data row1 col6" >2.5096</td>
#       <td id="T_0a4a3_row1_col7" class="data row1 col7" >1.3367</td>
#     </tr>
#     <tr>
#       <th id="T_0a4a3_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_0a4a3_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0a4a3_row2_col1" class="data row2 col1" >0.5556</td>
#       <td id="T_0a4a3_row2_col2" class="data row2 col2" >1.3280</td>
#       <td id="T_0a4a3_row2_col3" class="data row2 col3" >1.1231</td>
#       <td id="T_0a4a3_row2_col4" class="data row2 col4" >0.5815</td>
#       <td id="T_0a4a3_row2_col5" class="data row2 col5" >0.3130</td>
#       <td id="T_0a4a3_row2_col6" class="data row2 col6" >2.2161</td>
#       <td id="T_0a4a3_row2_col7" class="data row2 col7" >0.3133</td>
#     </tr>
#     <tr>
#       <th id="T_0a4a3_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_0a4a3_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_0a4a3_row3_col1" class="data row3 col1" >0.5732</td>
#       <td id="T_0a4a3_row3_col2" class="data row3 col2" >1.4324</td>
#       <td id="T_0a4a3_row3_col3" class="data row3 col3" >1.1596</td>
#       <td id="T_0a4a3_row3_col4" class="data row3 col4" >0.5625</td>
#       <td id="T_0a4a3_row3_col5" class="data row3 col5" >0.3241</td>
#       <td id="T_0a4a3_row3_col6" class="data row3 col6" >2.2467</td>
#       <td id="T_0a4a3_row3_col7" class="data row3 col7" >7.4767</td>
#     </tr>
#     <tr>
#       <th id="T_0a4a3_level0_row4" class="row_heading level0 row4" >catboost</th>
#       <td id="T_0a4a3_row4_col0" class="data row4 col0" >CatBoost Regressor</td>
#       <td id="T_0a4a3_row4_col1" class="data row4 col1" >0.5985</td>
#       <td id="T_0a4a3_row4_col2" class="data row4 col2" >1.4750</td>
#       <td id="T_0a4a3_row4_col3" class="data row4 col3" >1.1845</td>
#       <td id="T_0a4a3_row4_col4" class="data row4 col4" >0.5337</td>
#       <td id="T_0a4a3_row4_col5" class="data row4 col5" >0.3386</td>
#       <td id="T_0a4a3_row4_col6" class="data row4 col6" >2.3244</td>
#       <td id="T_0a4a3_row4_col7" class="data row4 col7" >1.5833</td>
#     </tr>
#     <tr>
#       <th id="T_0a4a3_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_0a4a3_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_0a4a3_row5_col1" class="data row5 col1" >0.6569</td>
#       <td id="T_0a4a3_row5_col2" class="data row5 col2" >1.4459</td>
#       <td id="T_0a4a3_row5_col3" class="data row5 col3" >
# 🔍 AU-ASM → FI-Hyy Transfer Results for GPP:
# Best Model: GradientBoostingRegressor(random_state=42)
# R²:   0.4722
# RMSE: 3.8359
# MAE:  3.3808
# ρ:    0.8469

# %%
import pandas as pd
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from pycaret.regression import *
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from scipy.stats import pearsonr

# ========================== 1. Site paths ==========================

# AU-ASM training data
au_met = xr.open_dataset("AU-ASM/AU-ASM_2011-2017_OzFlux_Met.nc")
au_flux = xr.open_dataset("AU-ASM/AU-ASM_2011-2017_OzFlux_Flux.nc")

# FI-Hyy test data (adjust paths as needed)
fi_met = xr.open_dataset("FI-Hyy/FI-Hyy_1996-2014_FLUXNET2015_Met.nc")
fi_flux = xr.open_dataset("FI-Hyy/FI-Hyy_1996-2014_FLUXNET2015_Flux.nc")

# ========================== 2. Feature definitions ==========================

features_raw = ['SWdown', 'LWdown', 'Tair', 'Qair', 'RH', 'Psurf', 'Wind',
                'CO2air', 'VPD', 'LAI', 'Ustar']
derived_features = ['SW_LAI', 'RH_Tair', 'SWdown_lag1', 'Tair_lag1']
target_var = 'NEE'  # or 'GPP'

# ========================== 3. Preprocessing ==========================

def preprocess(met_ds, flux_ds):
    met_df = met_ds.to_dataframe().reset_index()
    flux_df = flux_ds.to_dataframe().reset_index()
    df = pd.merge_asof(met_df.sort_values('time'),
                       flux_df.sort_values('time'),
                       on='time')
    df = df[['time'] + features_raw + ['GPP', 'NEE']].dropna()

    # Derived features
    df['SW_LAI'] = df['SWdown'] * df['LAI']
    df['RH_Tair'] = df['RH'] * df['Tair']
    df['SWdown_lag1'] = df['SWdown'].shift(1)
    df['Tair_lag1'] = df['Tair'].shift(1)

    df = df.dropna().set_index('time').sort_index()
    return df

# ========================== 4. Build train/test data ==========================

df_train = preprocess(au_met, au_flux)
df_test = preprocess(fi_met, fi_flux)

features_all = features_raw + derived_features

# ========================== 5. AutoML training (AU-ASM only) ==========================

train_data = pd.concat([df_train[features_all], df_train[target_var]], axis=1).reset_index(drop=True)

s = setup(
    data=train_data,
    target=target_var,
    session_id=42,
    train_size=0.999,
    fold_strategy='timeseries',
    fold=3,
    fold_shuffle=False,
    data_split_shuffle=False,
    preprocess=True,
    numeric_features=features_all,
    remove_multicollinearity=True,
    multicollinearity_threshold=0.95,
    verbose=False
)

best_model = compare_models(sort='R2')

# ========================== 6. Transfer evaluation (on FI-Hyy) ==========================

test_data = df_test[features_all].reset_index(drop=True)
true_vals = df_test[target_var].reset_index(drop=True)

preds = predict_model(best_model, data=test_data)
y_pred = preds['prediction_label'].values
y_true = true_vals.values

# ========================== 7. Metrics ==========================

rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mae = mean_absolute_error(y_true, y_pred)
r2 = r2_score(y_true, y_pred)
rho, _ = pearsonr(y_true, y_pred)

print(f"\n🔍 AU-ASM → FI-Hyy transfer results for {target_var}:")
print(f"Best model: {best_model}")
print(f"R²:   {r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"ρ:    {rho:.4f}")

# ========================== 8. Visualization: time series comparison ==========================

plt.figure(figsize=(12, 4))
plt.plot(df_test.index, y_true, label="Observed", alpha=0.7)
plt.plot(df_test.index, y_pred, label="Predicted", alpha=0.7)
plt.title(f"AU-ASM → FI-Hyy Transfer | {target_var} Prediction")
plt.xlabel("Time")
plt.ylabel(f"{target_var} (μmol m⁻² s⁻¹)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# #T_fc213 th {
#   text-align: left;
# }
# #T_fc213_row0_col0, #T_fc213_row0_col6, #T_fc213_row1_col0, #T_fc213_row1_col1, #T_fc213_row1_col2, #T_fc213_row1_col3, #T_fc213_row1_col4, #T_fc213_row1_col5, #T_fc213_row1_col6, #T_fc213_row2_col0, #T_fc213_row2_col1, #T_fc213_row2_col2, #T_fc213_row2_col3, #T_fc213_row2_col4, #T_fc213_row2_col5, #T_fc213_row2_col6, #T_fc213_row3_col0, #T_fc213_row3_col1, #T_fc213_row3_col2, #T_fc213_row3_col3, #T_fc213_row3_col4, #T_fc213_row3_col5, #T_fc213_row3_col6, #T_fc213_row4_col0, #T_fc213_row4_col1, #T_fc213_row4_col2, #T_fc213_row4_col3, #T_fc213_row4_col4, #T_fc213_row4_col5, #T_fc213_row4_col6, #T_fc213_row5_col0, #T_fc213_row5_col1, #T_fc213_row5_col2, #T_fc213_row5_col3, #T_fc213_row5_col4, #T_fc213_row5_col5, #
level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_fc213_row5_col0" class="data row5 col0" >Random Forest Regressor</td>
#       <td id="T_fc213_row5_col1" class="data row5 col1" >0.8091</td>
#       <td id="T_fc213_row5_col2" class="data row5 col2" >1.6875</td>
#       <td id="T_fc213_row5_col3" class="data row5 col3" >
# 🔍 AU-ASM → FI-Hyy Transfer Results for NEE:
# Best Model: GradientBoostingRegressor(random_state=42)
# R²:   -2.1934
# RMSE: 7.7223
# MAE:  7.3156
# ρ:    0.7516

# %% [markdown]
# ## FI-Hyy → US-UMB

# %%
import pandas as pd
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from pycaret.regression import *
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from scipy.stats import pearsonr

# ========================== 1. Site paths ==========================

# FI-Hyy training data
fi_met = xr.open_dataset("FI-Hyy/FI-Hyy_1996-2014_FLUXNET2015_Met.nc")
fi_flux = xr.open_dataset("FI-Hyy/FI-Hyy_1996-2014_FLUXNET2015_Flux.nc")

# US-UMB test data
us_met = xr.open_dataset("US-UMB/US-UMB_2000-2014_FLUXNET2015_Met.nc")
us_flux = xr.open_dataset("US-UMB/US-UMB_2000-2014_FLUXNET2015_Flux.nc")

# ========================== 2. Feature definitions ==========================

features_raw = ['SWdown', 'LWdown', 'Tair', 'Qair', 'RH', 'Psurf', 'Wind',
                'CO2air', 'VPD', 'LAI', 'Ustar']
derived_features = ['SW_LAI', 'RH_Tair', 'SWdown_lag1', 'Tair_lag1']
target_var = 'GPP'  # or 'NEE'

# ========================== 3. Preprocessing ==========================

def preprocess(met_ds, flux_ds):
    met_df = met_ds.to_dataframe().reset_index()
    flux_df = flux_ds.to_dataframe().reset_index()
    df = pd.merge_asof(met_df.sort_values('time'),
                       flux_df.sort_values('time'),
                       on='time')
    df = df[['time'] + features_raw + ['GPP', 'NEE']].dropna()

    # Derived features
    df['SW_LAI'] = df['SWdown'] * df['LAI']
    df['RH_Tair'] = df['RH'] * df['Tair']
    df['SWdown_lag1'] = df['SWdown'].shift(1)
    df['Tair_lag1'] = df['Tair'].shift(1)

    df = df.dropna().set_index('time').sort_index()
    return df

# ========================== 4. Build train/test data ==========================

df_train = preprocess(fi_met, fi_flux)
df_test = preprocess(us_met, us_flux)

features_all = features_raw + derived_features

# ========================== 5. AutoML training (FI-Hyy only) ==========================

train_data = pd.concat([df_train[features_all], df_train[target_var]], axis=1).reset_index(drop=True)

s = setup(
    data=train_data,
    target=target_var,
    session_id=42,
    train_size=0.999,
    fold_strategy='timeseries',
    fold=3,
    fold_shuffle=False,
    data_split_shuffle=False,
    preprocess=True,
    numeric_features=features_all,
    remove_multicollinearity=True,
    multicollinearity_threshold=0.95,
    verbose=False
)

best_model = compare_models(sort='R2')

# ========================== 6. Transfer evaluation (on US-UMB) ==========================

test_data = df_test[features_all].reset_index(drop=True)
true_vals = df_test[target_var].reset_index(drop=True)

preds = predict_model(best_model, data=test_data)
y_pred = preds['prediction_label'].values
y_true = true_vals.values

# ========================== 7. Metrics ==========================

rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mae = mean_absolute_error(y_true, y_pred)
r2 = r2_score(y_true, y_pred)
rho, _ = pearsonr(y_true, y_pred)

print(f"\n🔍 FI-Hyy → US-UMB transfer results for {target_var}:")
print(f"Best model: {best_model}")
print(f"R²:   {r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"ρ:    {rho:.4f}")

# ========================== 8. Visualization: time series comparison ==========================

plt.figure(figsize=(12, 4))
plt.plot(df_test.index, y_true, label="Observed", alpha=0.7)
plt.plot(df_test.index, y_pred, label="Predicted", alpha=0.7)
plt.title(f"FI-Hyy → US-UMB Transfer | {target_var} Prediction")
plt.xlabel("Time")
plt.ylabel(f"{target_var} (μmol m⁻² s⁻¹)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# #T_7b6fc th {
#   text-align: left;
# }
# #T_7b6fc_row0_col0, #T_7b6fc_row0_col6, #T_7b6fc_row1_col0, #T_7b6fc_row1_col1, #T_7b6fc_row1_col2, #T_7b6fc_row1_col3, #T_7b6fc_row1_col4, #T_7b6fc_row1_col5, #T_7b6fc_row2_col0, #T_7b6fc_row2_col1, #T_7b6fc_row2_col2, #T_7b6fc_row2_col3, #T_7b6fc_row2_col4, #T_7b6fc_row2_col5, #T_7b6fc_row2_col6, #T_7b6fc_row3_col0, #T_7b6fc_row3_col1, #T_7b6fc_row3_col2, #T_7b6fc_row3_col3, #T_7b6fc_row3_col4, #T_7b6fc_row3_col5, #T_7b6fc_row3_col6, #T_7b6fc_row4_col0, #T_7b6fc_row4_col1, #T_7b6fc_row4_col2, #T_7b6fc_row4_col3, #T_7b6fc_row4_col4, #T_7b6fc_row4_col5, #T_7b6fc_row4_col6, #T_7b6fc_row5_col0, #T_7b6fc_row5_col1, #T_7b6fc_row5_col2, #T_7b6fc_row5_col3, #T_7b6fc_row5_col4, #T_7b6fc_row5_col5, #T_7b6fc_row5_col6, #T_7b6fc_row6_col0, #T_7b6fc_row6_col1, #T_7b6fc_row6_col2, #T_7b6fc_row6_col3, #T_7b6fc_row6_col4, #T_7b6fc_row6_col5, #T_7b6fc_row6_col6, #T_7b6fc_row7_col0, #T_7b6fc_row7_col1, #T_7b6fc_row7_col2, #T_7b6fc_row7_col3, #T_7b6fc_row7_col4, #T_7b6fc_row7_col5, #T_7b6fc_row7_col6, #T_7b6fc_row8_col0, #T_7b6fc_row8_col1, #T_7b6fc_row8_col2, #T_7b6fc_row8_col3, #T_7b6fc_row8_col4, #T_7b6fc_row8_col5, #T_7b6fc_row8_col6, #T_7b6fc_row9_col0, #T_7b6fc_row9_col1, #T_7b6fc_row9_col2, #T_7b6fc_row9_col3, #T_7b6fc_row9_col4, #T_7b6fc_row9_col5, #T_7b6fc_row9_col6, #T_7b6fc_row10_col0, #T_7b6fc_row10_col1, #T_7b6fc_row10_col2, #T_7b6fc_row10_col3, #T_7b6fc_row10_col4, #T_7b6fc_row10_col5, #T_7b6fc_row10_col6, #T_7b6fc_row11_col0, #T_7b6fc_row11_col1, #T_7b6fc_row11_col2, #T_7b6fc_row11_col3, #T_7b6fc_row11_col4, #T_7b6fc_row11_col5, #T_7b6fc_row11_col6, #T_7b6fc_row12_col0, #T_7b6fc_row12_col1, #T_7b6fc_row12_col2, #T_7b6fc_row12_col3, #T_7b6fc_row12_col4, #T_7b6fc_row12_col5, #T_7b6fc_row12_col6, #T_7b6fc_row13_col0, #T_7b6fc_row13_col1, #T_7b6fc_row13_col2, #T_7b
row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_7b6fc_row1_col1" class="data row1 col1" >0.8318</td>
#       <td id="T_7b6fc_row1_col2" class="data row1 col2" >2.0504</td>
#       <td id="T_7b6fc_row1_col3" class="data row1 col3" >1.4272</td>
#       <td id="T_7b6fc_row1_col4" class="data row1 col4" >0.9262</td>
#       <td id="T_7b6fc_row1_col5" class="data row1 col5" >0.3178</td>
#       <td id="T_7b6fc_row1_col6" class="data row1 col6" >2.2306</td>
#       <td id="T_7b6fc_row1_col7" class="data row1 col7" >0.4467</td>
#     </tr>
#     <tr>
#       <th id="T_7b6fc_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_7b6fc_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_7b6fc_row2_col1" class="data row2 col1" >0.8512</td>
#       <td id="T_7b6fc_row2_col2" class="data row2 col2" >2.1118</td>
#       <td id="T_7b6fc_row2_col3" class="data row2 col3" >1.4466</td>
#       <td id="T_7b6fc_row2_col4" class="data row2 col4" >0.9243</td>
#       <td id="T_7b6fc_row2_col5" class="data row2 col5" >0.3116</td>
#       <td id="T_7b6fc_row2_col6" class="data row2 col6" >2.9043</td>
#       <td id="T_7b6fc_row2_col7" class="data row2 col7" >17.1967</td>
#     </tr>
#     <tr>
#       <th id="T_7b6fc_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_7b6fc_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_7b6fc_row3_col1" class="data row3 col1" >0.8494</td>
#       <td id="T_7b6fc_row3_col2" class="data row3 col2" >2.1334</td>
#       <td id="T_7b6fc_row3_col3" class="data row3 col3" >1.4551</td>
#       <td id="T_7b6fc_row3_col4" class="data row3 col4" >0.9234</td>
#       <td id="T_7b6fc_row3_col5" class="data row3 col5" >0.3036</td>
#       <td id="T_7b6fc_row3_col6" class="data row3 col6" >3.3862</td>
#       <td id="T_7b6fc_row3_col7" class="data row3 col7" >28.2033</td>
#     </tr>
#     <tr>
#       <th id="T_7b6fc_level0_row4" class="row_heading level0 row4" >catboost</th>
#       <td id="T_7b6fc_row4_col0" class="data row4 col0" >CatBoost Regressor</td>
#       <td id="T_7b6fc_row4_col1" class="data row4 col1" >0.8553</td>
#       <td id="T_7b6fc_row4_col2" class="data row4 col2" >2.1759</td>
#       <td id="T_7b6fc_row4_col3" class="data row4 col3" >1.4708</td>
#       <td id="T_7b6fc_row4_col4" class="data row4 col4" >0.9214</td>
#       <td id="T_7b6fc_row4_col5" class="data row4 col5" >0.3111</td>
#       <td id="T_7b6fc_row4_col6" class="data row4 col6" >2.8406</td>
#       <td id="T_7b6fc_row4_col7" class="data row4 col7" >3.1367</td>
#     </tr>
#     <tr>
#       <th id="T_7b6fc_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_7b6fc_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_7b6fc_row5_col1" class="data row5 col1" >0.9062</td>
#       <td id="T_7b6fc_row5_col2" class="data row5 col2" >2.4815</td>
#       <td id="T_7b6fc_row5_col3" class="data
# 🔍 FI-Hyy → US-UMB Transfer Results for GPP:
# Best Model: ExtraTreesRegressor(n_jobs=-1, random_state=42)
# R²:   0.8657
# RMSE: 2.6710
# MAE:  1.5389
# ρ:    0.9335

# %%
import pandas as pd
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from pycaret.regression import *
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from scipy.stats import pearsonr

# ========================== 1. 站点路径设置 ==========================

# FI-Hyy 训练数据
fi_met = xr.open_dataset("FI-Hyy/FI-Hyy_1996-2014_FLUXNET2015_Met.nc")
fi_flux = xr.open_dataset("FI-Hyy/FI-Hyy_1996-2014_FLUXNET2015_Flux.nc")

# US-UMB 测试数据
us_met = xr.open_dataset("US-UMB/US-UMB_2000-2014_FLUXNET2015_Met.nc")
us_flux = xr.open_dataset("US-UMB/US-UMB_2000-2014_FLUXNET2015_Flux.nc")

# ========================== 2. 特征定义 ==========================

features_raw = ['SWdown', 'LWdown', 'Tair', 'Qair', 'RH', 'Psurf', 'Wind',
                'CO2air', 'VPD', 'LAI', 'Ustar']
derived_features = ['SW_LAI', 'RH_Tair', 'SWdown_lag1', 'Tair_lag1']
target_var = 'NEE'  # ✅ 你也可以改为 GPP

# ========================== 3. 数据预处理函数 ==========================

def preprocess(met_ds, flux_ds):
    met_df = met_ds.to_dataframe().reset_index()
    flux_df = flux_ds.to_dataframe().reset_index()
    df = pd.merge_asof(met_df.sort_values('time'), flux_df.sort_values('time'), on='time')
    df = df[['time'] + features_raw + ['GPP', 'NEE']].dropna()

    # 派生特征
    df['SW_LAI'] = df['SWdown'] * df['LAI']
    df['RH_Tair'] = df['RH'] * df['Tair']
    df['SWdown_lag1'] = df['SWdown'].shift(1)
    df['Tair_lag1'] = df['Tair'].shift(1)
    df = df.dropna().set_index('time').sort_index()
    return df

# ========================== 4. 数据处理 ==========================

df_train = preprocess(fi_met, fi_flux)
df_test = preprocess(us_met, us_flux)

features_all = features_raw + derived_features

# ========================== 5. AutoML 训练（仅使用训练集） ==========================

train_data = pd.concat([df_train[features_all], df_train[target_var]], axis=1).reset_index(drop=True)

s = setup(
    data=train_data,
    target=target_var,
    session_id=42,
    train_size=0.999,
    fold_strategy='timeseries',
    fold=3,
    fold_shuffle=False,
    data_split_shuffle=False,
    preprocess=True,
    numeric_features=features_all,
    remove_multicollinearity=True,
    multicollinearity_threshold=0.95,
    verbose=False
)

best_model = compare_models(sort='R2')

# ========================== 6. 迁移评估（在 US-UMB 测试集上） ==========================

test_data = df_test[features_all].reset_index(drop=True)
true_vals = df_test[target_var].reset_index(drop=True)

preds = predict_model(best_model, data=test_data)
y_pred = preds['prediction_label'].values
y_true = true_vals.values

# ========================== 7. 指标评估 ==========================

rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mae = mean_absolute_error(y_true, y_pred)
r2 = r2_score(y_true, y_pred)
rho, _ = pearsonr(y_true, y_pred)

print(f"\n🔍 FI-Hyy → US-UMB Transfer Results for {target_var}:")
print(f"Best Model: {best_model}")
print(f"R²:   {r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"ρ:    {rho:.4f}")

# ========================== 8. 可视化：时间序列对比图 ==========================

plt.figure(figsize=(12, 4))
plt.plot(df_test.index, y_true, label="Observed", alpha=0.7)
plt.plot(df_test.index, y_pred, label="Predicted", alpha=0.7)
plt.title(f"FI-Hyy → US-UMB Transfer | {target_var} Prediction")
plt.xlabel("Time")
plt.ylabel(f"{target_var} (μmol m⁻² s⁻¹)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# #T_64a29 th {
#   text-align: left;
# }
# #T_64a29_row0_col0, #T_64a29_row1_col0, #T_64a29_row1_col1, #T_64a29_row1_col2, #T_64a29_row1_col3, #T_64a29_row1_col4, #T_64a29_row1_col5, #T_64a29_row1_col6, #T_64a29_row2_col0, #T_64a29_row2_col1, #T_64a29_row2_col2, #T_64a29_row2_col3, #T_64a29_row2_col4, #T_64a29_row2_col5, #T_64a29_row2_col6, #T_64a29_row3_col0, #T_64a29_row3_col1, #T_64a29_row3_col2, #T_64a29_row3_col3, #T_64a29_row3_col4, #T_64a29_row3_col5, #T_64a29_row3_col6, #T_64a29_row4_col0, #T_64a29_row4_col1, #T_64a29_row4_col2, #T_64a29_row4_col3, #T_64a29_row4_col4, #T_64a29_row4_col5, #T_64a29_row4_col6, #T_64a29_row5_col0, #T_64a29_row5_col1, #T_64a29_row5_col2, #T_64a29_row5_col3, #T_64a29_row5_col4, #T_64a29_row5_col5, #T_64a29_row5_col6, #T_64a29_row6_col0, #T_64a29_row6_col1, #T_64a29_row6_col2, #T_64a29_row6_col3, #T_64a29_row6_col4, #T_64a29_row6_col5, #T_64a29_row6_col6, #T_64a29_row7_col0, #T_64a29_row7_col1, #T_64a29_row7_col2, #T_64a29_row7_col3, #T_64a29_row7_col4, #T_64a29_row7_col5, #T_64a29_row7_col6, #T_64a29_row8_col0, #T_64a29_row8_col1, #T_64a29_row8_col2, #T_64a29_row8_col3, #T_64a29_row8_col4, #T_64a29_row8_col5, #T_64a29_row8_col6, #T_64a29_row9_col0, #T_64a29_row9_col1, #T_64a29_row9_col2, #T_64a29_row9_col3, #T_64a29_row9_col4, #T_64a29_row9_col5, #T_64a29_row9_col6, #T_64a29_row10_col0, #T_64a29_row10_col1, #T_64a29_row10_col2, #T_64a29_row10_col3, #T_64a29_row10_col4, #T_64a29_row10_col5, #T_64a29_row10_col6, #T_64a29_row11_col0, #T_64a29_row11_col1, #T_64a29_row11_col2, #T_64a29_row11_col3, #T_64a29_row11_col4, #T_64a29_row11_col5, #T_64a29_row11_col6, #T_64a29_row12_col0, #T_64a29_row12_col1, #T_64a29_row12_col2, #T_64a29_row12_col3, #T_64a29_row12_col4, #T_64a29_row12_col5, #T_64a29_row12_col6, #T_64a29_row13_col0, #T_64a29_row13_col1, #T_64a29_row13_col2, #T_64a29_row13_col3, #T_64a29_row13_col4, #T_64a29_row13_col5, #T_64a29_row13_col6, #T_64a29_row14_col0, #T_64a29_row14_col1, #T_64a29_row14_col2, #T_64a29_row14_col3, #T_64a29_row14_col4, #T_64a29_row14_col5, #T_64a29_row14_col6, #T_64a29_row15_col0, #T_64a29_row15_col1, #T_64a29_row15_col2, #T_64a29_row15_col3, #T_64a29_row15_col4, #T_64a29_row15_col5, #T_64a29_row15_col6, #T_64a29_row16_col0, #T_64a29_row16_col1, #T_64a29_row16_col2, #T_64a29_row16_col3, #T_64a29_row16_col4, #T_64a29_row16_col5, #T_64a29_row16_col6, #T_64a29_row17_col0, #T_64a29_row17_col1, #T_64a29_row17_col2, #T_64a29_row17_col3, #T_64a29_row17_col4, #T_64a29_row17_col5, #T_64a29_row17_col6, #T_64a29_row18_col0, #T_64a29_row18_col1, #T_64a29_row18_col2, #T_64a29_row18_col3, #T_64a29_row18_col4, #T_64a29_row18_col5, #T_64a29_row18_col6, #T_64a29_row19_col0, #T_64a29_row19_col1, #T_64a29_row19_col2, #T_64a29_row19_col3, #T_64a29_row19_col4, #T_64a29_row19_col5, #T_64a29_row19_col6 {
#   text-align: left;
# }
# #T_64a29_row0_col1, #T_64a29_row0_col2, #T_64a29_row0_col3, #T_64a29_row0_col4, #T_64a29_row0_col5, #T_64a29_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_64a29_row0_col7, #T_64a29_row1_col7, #T_64a29_row2_col7, #T_64a29_row3_col7, #T_64a29_row4_col7, #T_64a29_row5_col7, #T_64a29_row6_col7, #T_64a29_row7_col7, #T_64a29_row8_col7, #T_64a29_row9_col7, #T_64a29_row10_col7, #T_64a29_row11_col7, #T_64a29_row12_col7, #T_64a29_row13_col7, #T_64a29_row15_col7, #T_64a29_row16_col7, #T_64a29_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_64a29_row14_col7, #T_64a29_row18_col7, #T_64a29_row19_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_64a29">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64a29_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_64a29_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_64a29_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_64a29_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_64a29_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_64a29_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_64a29_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_64a29_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64a29_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_64a29_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_64a29_row0_col1" class="data row0 col1" >0.7946</td>
#       <td id="T_64a29_row0_col2" class="data row0 col2" >1.6646</td>
#       <td id="T_64a29_row0_col3" class="data row0 col3" >1.2851</td>
#       <td id="T_64a29_row0_col4" class="data row0 col4" >0.9111</td>
#       <td id="T_64a29_row0_col5" class="data row0 col5" >0.2803</td>
#       <td id="T_64a29_row0_col6" class="data row0 col6" >1.4096</td>
#       <td id="T_64a29_row0_col7" class="data row0 col7" >6.1400</td>
#     </tr>
#     <tr>
#       <th id="T_64a29_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_64a29_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_64a29_row1_col1" class="data row1 col1" >0.7999</td>
#       <td id="T_64a29_row1_col2" class="data row1 col2" >1.6784</td>
#       <td id="T_64a29_row1_col3" class="data row1 col3" >1.2920</td>
#       <td id="T_64a29_row1_col4" class="data row1 col4" >0.9099</td>
#       <td id="T_64a29_row1_col5" class="data row1 col5" >0.2888</td>
#       <td id="T_64a29_row1_col6" class="data row1 col6" >1.4726</td>
#       <td id="T_64a29_row1_col7" class="data row1 col7" >0.9867</td>
#     </tr>
#     <tr>
#       <th id="T_64a29_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_64a29_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_64a29_row2_col1" class="data row2 col1" >0.8149</td>
#       <td id="T_64a29_row2_col2" class="data row2 col2" >1.7240</td>
#       <td id="T_64a29_row2_col3" class="data row2 col3" >1.3102</td>
#       <td id="T_64a29_row2_col4" class="data row2 col4" >0.9071</td>
#       <td id="T_64a29_row2_col5" class="data row2 col5" >0.2916</td>
#       <td id="T_64a29_row2_col6" class="data row2 col6" >1.5094</td>
#       <td id="T_64a29_row2_col7" class="data row2 col7" >4.0900</td>
#     </tr>
#     <tr>
#       <th id="T_64a29_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_64a29_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_64a29_row3_col1" class="data row3 col1" >0.8299</td>
#       <td id="T_64a29_row3_col2" class="data row3 col2" >1.7873</td>
#       <td id="T_64a29_row3_col3" class="data row3 col3" >1.3309</td>
#       <td id="T_64a29_row3_col4" class="data row3 col4" >0.9046</td>
#       <td id="T_64a29_row3_col5" class="data row3 col5" >0.2947</td>
#       <td id="T_64a29_row3_col6" class="data row3 col6" >1.5836</td>
#       <td id="T_64a29_row3_col7" class="data row3 col7" >17.1867</td>
#     </tr>
#     <tr>
#       <th id="T_64a29_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_64a29_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_64a29_row4_col1" class="data row4 col1" >0.8391</td>
#       <td id="T_64a29_row4_col2" class="data row4 col2" >1.7968</td>
#       <td id="T_64a29_row4_col3" class="data row4 col3" >1.3371</td>
#       <td id="T_64a29_row4_col4" class="data row4 col4" >0.9036</td>
#       <td id="T_64a29_row4_col5" class="data row4 col5" >0.3020</td>
#       <td id="T_64a29_row4_col6" class="data row4 col6" >1.5509</td>
#       <td id="T_64a29_row4_col7" class="data row4 col7" >24.6800</td>
#     </tr>
#     <tr>
#       <th id="T_64a29_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_64a29_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_64a29_row5_col1" class="data row5 col1" >0.8449</td>
#       <td id="T_64a29_row5_col2" class="data row5 col2" >1.8557</td>
#       <td id="T_64a29_row5_col3" class="data
# 🔍 FI-Hyy → US-UMB Transfer Results for NEE:
# Best Model: ExtraTreesRegressor(n_jobs=-1, random_state=42)
# R²:   0.8193
# RMSE: 2.6684
# MAE:  1.5463
# ρ:    0.9084

# %% [markdown]
# ## US-UMB → AU-ASM

# %%
import pandas as pd
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from pycaret.regression import *
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from scipy.stats import pearsonr

# ========================== 1. Site paths ==========================

# US-UMB training data
us_met = xr.open_dataset("US-UMB/US-UMB_2000-2014_FLUXNET2015_Met.nc")
us_flux = xr.open_dataset("US-UMB/US-UMB_2000-2014_FLUXNET2015_Flux.nc")

# AU-ASM test data
au_met = xr.open_dataset("AU-ASM/AU-ASM_2011-2017_OzFlux_Met.nc")
au_flux = xr.open_dataset("AU-ASM/AU-ASM_2011-2017_OzFlux_Flux.nc")

# ========================== 2. Feature definitions ==========================

features_raw = ['SWdown', 'LWdown', 'Tair', 'Qair', 'RH', 'Psurf', 'Wind',
                'CO2air', 'VPD', 'LAI', 'Ustar']
derived_features = ['SW_LAI', 'RH_Tair', 'SWdown_lag1', 'Tair_lag1']
target_var = 'GPP'  # or 'NEE'

# ========================== 3. Preprocessing ==========================

def preprocess(met_ds, flux_ds):
    met_df = met_ds.to_dataframe().reset_index()
    flux_df = flux_ds.to_dataframe().reset_index()
    df = pd.merge_asof(met_df.sort_values('time'),
                       flux_df.sort_values('time'),
                       on='time')
    df = df[['time'] + features_raw + ['GPP', 'NEE']].dropna()

    # Derived features
    df['SW_LAI'] = df['SWdown'] * df['LAI']
    df['RH_Tair'] = df['RH'] * df['Tair']
    df['SWdown_lag1'] = df['SWdown'].shift(1)
    df['Tair_lag1'] = df['Tair'].shift(1)

    df = df.dropna().set_index('time').sort_index()
    return df

# ========================== 4. Build train/test data ==========================

df_train = preprocess(us_met, us_flux)
df_test = preprocess(au_met, au_flux)

features_all = features_raw + derived_features

# ========================== 5. AutoML training (US-UMB only) ==========================

train_data = pd.concat([df_train[features_all], df_train[target_var]], axis=1).reset_index(drop=True)

s = setup(
    data=train_data,
    target=target_var,
    session_id=42,
    train_size=0.999,
    fold_strategy='timeseries',
    fold=3,
    fold_shuffle=False,
    data_split_shuffle=False,
    preprocess=True,
    numeric_features=features_all,
    remove_multicollinearity=True,
    multicollinearity_threshold=0.95,
    verbose=False
)

best_model = compare_models(sort='R2')

# ========================== 6. Transfer evaluation (on AU-ASM) ==========================

test_data = df_test[features_all].reset_index(drop=True)
true_vals = df_test[target_var].reset_index(drop=True)

preds = predict_model(best_model, data=test_data)
y_pred = preds['prediction_label'].values
y_true = true_vals.values

# ========================== 7. Metrics ==========================

rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mae = mean_absolute_error(y_true, y_pred)
r2 = r2_score(y_true, y_pred)
rho, _ = pearsonr(y_true, y_pred)

print(f"\n🔍 US-UMB → AU-ASM transfer results for {target_var}:")
print(f"Best model: {best_model}")
print(f"R²:   {r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"ρ:    {rho:.4f}")

# ========================== 8. Visualization: time series comparison ==========================

plt.figure(figsize=(12, 4))
plt.plot(df_test.index, y_true, label="Observed", alpha=0.7)
plt.plot(df_test.index, y_pred, label="Predicted", alpha=0.7)
plt.title(f"US-UMB → AU-ASM Transfer | {target_var} Prediction")
plt.xlabel("Time")
plt.ylabel(f"{target_var} (μmol m⁻² s⁻¹)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# #T_59ac3 th {
#   text-align: left;
# }
# #T_59ac3_row0_col0, #T_59ac3_row0_col5, #T_59ac3_row1_col0, #T_59ac3_row1_col1, #T_59ac3_row1_col2, #T_59ac3_row1_col3, #T_59ac3_row1_col4, #T_59ac3_row1_col5, #T_59ac3_row1_col6, #T_59ac3_row2_col0, #T_59ac3_row2_col1, #T_59ac3_row2_col2, #T_59ac3_row2_col3, #T_59ac3_row2_col4, #T_59ac3_row2_col5, #T_59ac3_row2_col6, #T_59ac3_row3_col0, #T_59ac3_row3_col1, #T_59ac3_row3_col2, #T_59ac3_row3_col3, #T_59ac3_row3_col4, #T_59ac3_row3_col6, #T_59ac3_row4_col0, #T_59ac3_row4_col1, #T_59ac3_row4_col2, #T_59ac3_row4_col3, #T_59ac3_row4_col4, #T_59ac3_row4_col5, #T_59ac3_row4_col6, #T_59ac3_row5_col0, #T_59ac3_row5_col1, #T_59ac3_row5_col2, #T_59ac3_row5_col3, #T_59ac3_row5_col4, #T_59ac3_row5_col5, #T_59ac3_row5_col6, #T_59ac3_row6_col0, #T_59ac3_row6_col1, #T_59ac3_row6_col2, #T_59ac3_row6_col3, #T_59ac3_row6_col4, #T_59ac3_row6_col5, #T_59ac3_row6_col6, #T_59ac3_row7_col0, #T_59ac3_row7_col1, #T_59ac3_row7_col2, #T_59ac3_row7_col3, #T_59ac3_row7_col4, #T_59ac3_row7_col5, #T_59ac3_row7_col6, #T_59ac3_row8_col0, #T_59ac3_row8_col1, #T_59ac3_row8_col2, #T_59ac3_row8_col3, #T_59ac3_row8_col4, #T_59ac3_row8_col5, #T_59ac3_row8_col6, #T_59ac3_row9_col0, #T_59ac3_row9_col1, #T_59ac3_row9_col2, #T_59ac3_row9_col3, #T_59ac3_row9_col4, #T_59ac3_row9_col5, #T_59ac3_row9_col6, #T_59ac3_row10_col0, #T_59ac3_row10_col1, #T_59ac3_row10_col2, #T_59ac3_row10_col3, #T_59ac3_row10_col4, #T_59ac3_row10_col5, #T_59ac3_row10_col6, #T_59ac3_row11_col0, #T_59ac3_row11_col1, #T_59ac3_row11_col2, #T_59ac3_row11_col3, #T_59ac3_row11_col4, #T_59ac3_row11_col5, #T_59ac3_row11_col6, #T_59ac3_row12_col0, #T_59ac3_row12_col1, #T_59ac3_row12_col2, #T_59ac3_row12_col3, #T_59ac3_row12_col4, #T_59ac3_
level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_59ac3_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#       <td id="T_59ac3_row1_col1" class="data row1 col1" >1.2008</td>
#       <td id="T_59ac3_row1_col2" class="data row1 col2" >5.0133</td>
#       <td id="T_59ac3_row1_col3" class="data row1 col3" >2.2305</td>
#       <td id="T_59ac3_row1_col4" class="data row1 col4" >0.9105</td>
#       <td id="T_59ac3_row1_col5" class="data row1 col5" >0.4006</td>
#       <td id="T_59ac3_row1_col6" class="data row1 col6" >3.5279</td>
#       <td id="T_59ac3_row1_col7" class="data row1 col7" >1.6000</td>
#     </tr>
#     <tr>
#       <th id="T_59ac3_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_59ac3_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_59ac3_row2_col1" class="data row2 col1" >1.2168</td>
#       <td id="T_59ac3_row2_col2" class="data row2 col2" >5.0543</td>
#       <td id="T_59ac3_row2_col3" class="data row2 col3" >2.2418</td>
#       <td id="T_59ac3_row2_col4" class="data row2 col4" >0.9098</td>
#       <td id="T_59ac3_row2_col5" class="data row2 col5" >0.3929</td>
#       <td id="T_59ac3_row2_col6" class="data row2 col6" >4.6610</td>
#       <td id="T_59ac3_row2_col7" class="data row2 col7" >2.8400</td>
#     </tr>
#     <tr>
#       <th id="T_59ac3_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_59ac3_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_59ac3_row3_col1" class="data row3 col1" >1.2295</td>
#       <td id="T_59ac3_row3_col2" class="data row3 col2" >5.0968</td>
#       <td id="T_59ac3_row3_col3" class="data row3 col3" >2.2511</td>
#       <td id="T_59ac3_row3_col4" class="data row3 col4" >0.9091</td>
#       <td id="T_59ac3_row3_col5" class="data row3 col5" >0.3927</td>
#       <td id="T_59ac3_row3_col6" class="data row3 col6" >5.4059</td>
#       <td id="T_59ac3_row3_col7" class="data row3 col7" >14.3367</td>
#     </tr>
#     <tr>
#       <th id="T_59ac3_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_59ac3_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_59ac3_row4_col1" class="data row4 col1" >1.2170</td>
#       <td id="T_59ac3_row4_col2" class="data row4 col2" >5.1585</td>
#       <td id="T_59ac3_row4_col3" class="data row4 col3" >2.2656</td>
#       <td id="T_59ac3_row4_col4" class="data row4 col4" >0.9080</td>
#       <td id="T_59ac3_row4_col5" class="data row4 col5" >0.4217</td>
#       <td id="T_59ac3_row4_col6" class="data row4 col6" >2.7331</td>
#       <td id="T_59ac3_row4_col7" class="data row4 col7" >7.9133</td>
#     </tr>
#     <tr>
#       <th id="T_59ac3_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_59ac3_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_59ac3_row5_col1" class="data row5 col1" >1.2561</td>
#       <td id="T_59ac3_row5_col2" class="data row5 col2" >5.4779</td>
#       <td id="T_59ac3_row5_col3" class="data
# 🔍 US-UMB → AU-ASM Transfer Results for GPP:
# Best Model: LGBMRegressor(n_jobs=-1, random_state=42)
# R²:   0.3027
# RMSE: 1.6330
# MAE:  0.7550
# ρ:    0.7072

# %%
import pandas as pd
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from pycaret.regression import *
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from scipy.stats import pearsonr

# ========================== 1. Site paths ==========================

# US-UMB training data
us_met = xr.open_dataset("US-UMB/US-UMB_2000-2014_FLUXNET2015_Met.nc")
us_flux = xr.open_dataset("US-UMB/US-UMB_2000-2014_FLUXNET2015_Flux.nc")

# AU-ASM test data
au_met = xr.open_dataset("AU-ASM/AU-ASM_2011-2017_OzFlux_Met.nc")
au_flux = xr.open_dataset("AU-ASM/AU-ASM_2011-2017_OzFlux_Flux.nc")

# ========================== 2. Feature definitions ==========================

features_raw = ['SWdown', 'LWdown', 'Tair', 'Qair', 'RH', 'Psurf', 'Wind',
                'CO2air', 'VPD', 'LAI', 'Ustar']
derived_features = ['SW_LAI', 'RH_Tair', 'SWdown_lag1', 'Tair_lag1']
target_var = 'NEE'  # or 'GPP'

# ========================== 3. Preprocessing ==========================

def preprocess(met_ds, flux_ds):
    met_df = met_ds.to_dataframe().reset_index()
    flux_df = flux_ds.to_dataframe().reset_index()
    df = pd.merge_asof(met_df.sort_values('time'),
                       flux_df.sort_values('time'),
                       on='time')
    df = df[['time'] + features_raw + ['GPP', 'NEE']].dropna()

    # Derived features
    df['SW_LAI'] = df['SWdown'] * df['LAI']
    df['RH_Tair'] = df['RH'] * df['Tair']
    df['SWdown_lag1'] = df['SWdown'].shift(1)
    df['Tair_lag1'] = df['Tair'].shift(1)

    df = df.dropna().set_index('time').sort_index()
    return df

# ========================== 4. Build train/test data ==========================

df_train = preprocess(us_met, us_flux)
df_test = preprocess(au_met, au_flux)

features_all = features_raw + derived_features

# ========================== 5. AutoML training (US-UMB only) ==========================

train_data = pd.concat([df_train[features_all], df_train[target_var]], axis=1).reset_index(drop=True)

s = setup(
    data=train_data,
    target=target_var,
    session_id=42,
    train_size=0.999,
    fold_strategy='timeseries',
    fold=3,
    fold_shuffle=False,
    data_split_shuffle=False,
    preprocess=True,
    numeric_features=features_all,
    remove_multicollinearity=True,
    multicollinearity_threshold=0.95,
    verbose=False
)

best_model = compare_models(sort='R2')

# ========================== 6. Transfer evaluation (on AU-ASM) ==========================

test_data = df_test[features_all].reset_index(drop=True)
true_vals = df_test[target_var].reset_index(drop=True)

preds = predict_model(best_model, data=test_data)
y_pred = preds['prediction_label'].values
y_true = true_vals.values

# ========================== 7. Metrics ==========================

rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mae = mean_absolute_error(y_true, y_pred)
r2 = r2_score(y_true, y_pred)
rho, _ = pearsonr(y_true, y_pred)

print(f"\n🔍 US-UMB → AU-ASM transfer results for {target_var}:")
print(f"Best model: {best_model}")
print(f"R²:   {r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"ρ:    {rho:.4f}")

# ========================== 8. Visualization: time series comparison ==========================

plt.figure(figsize=(12, 4))
plt.plot(df_test.index, y_true, label="Observed", alpha=0.7)
plt.plot(df_test.index, y_pred, label="Predicted", alpha=0.7)
plt.title(f"US-UMB → AU-ASM Transfer | {target_var} Prediction")
plt.xlabel("Time")
plt.ylabel(f"{target_var} (μmol m⁻² s⁻¹)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# #T_18565 th {
#   text-align: left;
# }
# #T_18565_row0_col0, #T_18565_row0_col1, #T_18565_row0_col5, #T_18565_row1_col0, #T_18565_row1_col2, #T_18565_row1_col3, #T_18565_row1_col4, #T_18565_row1_col6, #T_18565_row2_col0, #T_18565_row2_col1, #T_18565_row2_col2, #T_18565_row2_col3, #T_18565_row2_col4, #T_18565_row2_col5, #T_18565_row2_col6, #T_18565_row3_col0, #T_18565_row3_col1, #T_18565_row3_col2, #T_18565_row3_col3, #T_18565_row3_col4, #T_18565_row3_col5, #T_18565_row3_col6, #T_18565_row4_col0, #T_18565_row4_col1, #T_18565_row4_col2, #T_18565_row4_col3, #T_18565_row4_col4, #T_18565_row4_col5, #T_18565_row4_col6, #T_18565_row5_col0, #T_18565_row5_col1, #T_18565_row5_col2, #T_18565_row5_col3, #T_